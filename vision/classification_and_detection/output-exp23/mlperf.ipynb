# %% [markdown]
# # Tool to extract usefull information from mlperf trace

# %%
# %matplotlib inline
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

import json
import os
import seaborn as sns
from operator import itemgetter
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

figsize=(10, 5)
font=10

plt.figure(dpi=600)
plt.rc('xtick', labelsize=font) 
plt.rc('font', size=font)
sns.set(font_scale=1.4, style="whitegrid");

# %%
def trace_to_df(fname):
    with open(fname, "r") as f:
        print(f)
        j = json.load(f)
    if type(j) == dict:
        j = j['traceEvents']
        
    result = []
    for item in j:
        name = item['name']
        if name not in ["Latency", "Sample", "QuerySamplesComplete", "IssueQuery"]:
            continue

        args = item.get('args')
        d = {"ts": item['ts'], "name": name, "dur": item.get("dur")}

        if name == "Latency":
            d["issue_delay"] = args["issue_delay"] / 1e3
            d["issue_to_done"] = args["issue_to_done"] / 1e3
            result.append(d)
        elif name == "Sample":
            if args:
                d["issue_start_ns"] = args["issue_start_ns"]
                d["complete_ns"] = args["complete_ns"]
                d["issue_to_done"] = (args["complete_ns"] - args["issue_start_ns"]) / 1e3
                result.append(d)
        elif name == "QuerySamplesComplete":
            result.append(d)
        elif name == "IssueQuery":
            result.append(d)

    df = pd.DataFrame(result)
    df = df.sort_values(by=["ts"])
    return df

BINS = 10

# %%
# Fixing bin edges
HIST_BINS = np.linspace(0, 1000000, 100)

# %%
df = trace_to_df('/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/none-resnet-1-32-S-1-10/mlperf_log_trace.json')
df.describe()
# Out:
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/none-resnet-1-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
#                  ts           dur   issue_delay  issue_to_done  \
# count  4.802000e+04  24010.000000  1.200500e+04   2.401000e+04
# mean   4.133834e+07   3873.221525  1.697624e+07   1.101642e+07
# std    2.852758e+07   7212.683331  1.416478e+07   2.908724e+06
# min    1.960050e+05      3.011000  2.220000e-01   1.463773e+05
# 25%    1.781401e+07      6.087000  2.188979e+06   1.214575e+07
# 50%    3.751535e+07     45.319500  1.575882e+07   1.226124e+07
# 75%    5.730396e+07   5077.102750  2.938598e+07   1.230784e+07
# max    1.156422e+08  85201.312000  4.319503e+07   1.314071e+07
#
#        issue_start_ns   complete_ns
# count    1.200500e+04  1.200500e+04
# mean     1.697624e+10  2.799266e+10
# std      1.416478e+10  1.591214e+10
# min      2.220000e+02  1.463859e+08
# 25%      2.188979e+09  1.435780e+10
# 50%      1.575882e+10  2.800297e+10
# 75%      2.938598e+10  4.166818e+10
# max      4.319503e+10  5.553629e+10

# %%
df["name"].unique()
# Out:
# array(['Sample', 'Latency', 'IssueQuery', 'QuerySamplesComplete'],
#       dtype=object)

# %%
df
# Out:
#                  ts                  name      dur  issue_delay  \
# 32     1.960050e+05                Sample      NaN          NaN
# 31     1.960050e+05               Latency      NaN        8.660
# 0      1.960152e+05            IssueQuery  117.724          NaN
# 42     2.132605e+05                Sample      NaN          NaN
# 41     2.132605e+05               Latency      NaN       88.964
# ...             ...                   ...      ...          ...
# 48007  1.156336e+08  QuerySamplesComplete    5.511          NaN
# 48010  1.156343e+08  QuerySamplesComplete    5.612          NaN
# 48013  1.156369e+08  QuerySamplesComplete    6.510          NaN
# 48016  1.156420e+08  QuerySamplesComplete   10.615          NaN
# 48019  1.156422e+08  QuerySamplesComplete    5.915          NaN
#
#        issue_to_done  issue_start_ns  complete_ns
# 32        146377.280          8660.0  146385940.0
# 31        146377.280             NaN          NaN
# 0                NaN             NaN          NaN
# 42        158765.715         88964.0  158854679.0
# 41        158765.715             NaN          NaN
# ...              ...             ...          ...
# 48007            NaN             NaN          NaN
# 48010            NaN             NaN          NaN
# 48013            NaN             NaN          NaN
# 48016            NaN             NaN          NaN
# 48019            NaN             NaN          NaN
#
# [48020 rows x 7 columns]

# %%
df1 = df[df["name"].isin(["Sample"])]
df1
# Out:
#                  ts    name  dur  issue_delay  issue_to_done  issue_start_ns  \
# 32     1.960050e+05  Sample  NaN          NaN   1.463773e+05    8.660000e+03
# 42     2.132605e+05  Sample  NaN          NaN   1.587657e+05    8.896400e+04
# 49     2.151299e+05  Sample  NaN          NaN   1.805407e+05    6.118800e+04
# 56     2.222754e+05  Sample  NaN          NaN   2.050707e+05    8.422600e+04
# 71     2.367617e+05  Sample  NaN          NaN   2.383824e+05    1.121140e+05
# ...             ...     ...  ...          ...            ...             ...
# 48006  6.018522e+07  Sample  NaN          NaN   1.226478e+07    4.318361e+10
# 48009  6.019079e+07  Sample  NaN          NaN   1.225549e+07    4.318802e+10
# 48012  6.019285e+07  Sample  NaN          NaN   1.224902e+07    4.319503e+10
# 48018  6.019572e+07  Sample  NaN          NaN   1.225424e+07    4.319224e+10
# 48015  6.019789e+07  Sample  NaN          NaN   1.225018e+07    4.319395e+10
#
#         complete_ns
# 32     1.463859e+08
# 42     1.588547e+08
# 49     1.806019e+08
# 56     2.051549e+08
# 71     2.384945e+08
# ...             ...
# 48006  5.544839e+10
# 48009  5.544351e+10
# 48012  5.544405e+10
# 48018  5.544648e+10
# 48015  5.544414e+10
#
# [12005 rows x 7 columns]

# %%
df1 = df[df["name"].isin(["IssueQuery"])]
df1
# Out:
#                  ts        name       dur  issue_delay  issue_to_done  \
# 0      1.960152e+05  IssueQuery   117.724          NaN            NaN
# 1      2.133538e+05  IssueQuery    73.206          NaN            NaN
# 2      2.151961e+05  IssueQuery  1279.242          NaN            NaN
# 3      2.223629e+05  IssueQuery    63.277          NaN            NaN
# 4      2.368800e+05  IssueQuery   114.567          NaN            NaN
# ...             ...         ...       ...          ...            ...
# 44163  1.033688e+08  IssueQuery  9974.363          NaN            NaN
# 44170  1.033788e+08  IssueQuery  9063.663          NaN            NaN
# 44171  1.033879e+08  IssueQuery    79.233          NaN            NaN
# 44181  1.033880e+08  IssueQuery  3874.435          NaN            NaN
# 44182  1.033918e+08  IssueQuery  5538.585          NaN            NaN
#
#        issue_start_ns  complete_ns
# 0                 NaN          NaN
# 1                 NaN          NaN
# 2                 NaN          NaN
# 3                 NaN          NaN
# 4                 NaN          NaN
# ...               ...          ...
# 44163             NaN          NaN
# 44170             NaN          NaN
# 44171             NaN          NaN
# 44181             NaN          NaN
# 44182             NaN          NaN
#
# [12005 rows x 7 columns]

# %%
df1 = df[df["name"].isin(["Latency"])]
df1
# Out:
#                  ts     name  dur   issue_delay  issue_to_done  \
# 31     1.960050e+05  Latency  NaN  8.660000e+00   1.463773e+05
# 41     2.132605e+05  Latency  NaN  8.896400e+01   1.587657e+05
# 48     2.151299e+05  Latency  NaN  6.118800e+01   1.805407e+05
# 55     2.222754e+05  Latency  NaN  8.422600e+01   2.050707e+05
# 70     2.367617e+05  Latency  NaN  1.121140e+02   2.383824e+05
# ...             ...      ...  ...           ...            ...
# 48005  6.018522e+07  Latency  NaN  4.318361e+07   1.226478e+07
# 48008  6.019079e+07  Latency  NaN  4.318802e+07   1.225549e+07
# 48011  6.019285e+07  Latency  NaN  4.319503e+07   1.224902e+07
# 48017  6.019572e+07  Latency  NaN  4.319224e+07   1.225424e+07
# 48014  6.019789e+07  Latency  NaN  4.319395e+07   1.225018e+07
#
#        issue_start_ns  complete_ns
# 31                NaN          NaN
# 41                NaN          NaN
# 48                NaN          NaN
# 55                NaN          NaN
# 70                NaN          NaN
# ...               ...          ...
# 48005             NaN          NaN
# 48008             NaN          NaN
# 48011             NaN          NaN
# 48017             NaN          NaN
# 48014             NaN          NaN
#
# [12005 rows x 7 columns]

# %%
df1 = df[df["name"].isin(["QuerySamplesComplete"])]
df1
# Out:
#                  ts                  name     dur  issue_delay  issue_to_done  \
# 33     3.423921e+05  QuerySamplesComplete  26.157          NaN            NaN
# 43     3.721166e+05  QuerySamplesComplete  19.930          NaN            NaN
# 50     3.957332e+05  QuerySamplesComplete  26.923          NaN            NaN
# 57     4.274315e+05  QuerySamplesComplete  21.168          NaN            NaN
# 72     4.752575e+05  QuerySamplesComplete  20.600          NaN            NaN
# ...             ...                   ...     ...          ...            ...
# 48007  1.156336e+08  QuerySamplesComplete   5.511          NaN            NaN
# 48010  1.156343e+08  QuerySamplesComplete   5.612          NaN            NaN
# 48013  1.156369e+08  QuerySamplesComplete   6.510          NaN            NaN
# 48016  1.156420e+08  QuerySamplesComplete  10.615          NaN            NaN
# 48019  1.156422e+08  QuerySamplesComplete   5.915          NaN            NaN
#
#        issue_start_ns  complete_ns
# 33                NaN          NaN
# 43                NaN          NaN
# 50                NaN          NaN
# 57                NaN          NaN
# 72                NaN          NaN
# ...               ...          ...
# 48007             NaN          NaN
# 48010             NaN          NaN
# 48013             NaN          NaN
# 48016             NaN          NaN
# 48019             NaN          NaN
#
# [12005 rows x 7 columns]

# %% [markdown]
# # server scenario

# %%
import pandas as pd
import glob
# import plotly.plotly as py
import plotly.graph_objs as go

from plotly import tools
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True) 

import numpy as np
import matplotlib.pyplot as plt
# include if using a Jupyter notebook
# %matplotlib inline

path = "/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/"
all_files = glob.glob(path + "*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True)
df.head()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#   benchmark k8senv  sbatch  numctn cscenario  cbatch  reps         qps  \
# 0    resnet   none      32       1   offline       1    10  105.314230
# 1    resnet   none      32       2   offline       1    10  137.215083
# 2    resnet   none      32       4   offline       1    10  141.234295
# 3    resnet   none      32       8   offline       1    10  141.248409
# 4    resnet   none      32      16   offline       1    10  139.382784
#
#         mean        p50        p80        p90        p95        p99       p999
# 0  33.892380  33.883744  53.844176  60.709598  64.150449  67.037034  67.582270
# 1  18.650120  18.800309  27.669836  30.665241  32.189566  33.991337  34.563036
# 2  16.715752  16.699866  25.471223  28.125930  29.463639  30.905943  31.838715
# 3  16.735231  16.996240  24.861762  27.755312  29.215132  30.567862  32.607023
# 4  16.578870  16.798297  24.766076  27.574967  29.119341  30.648233  33.347896

# %%
import pandas as pd
import glob
# import plotly.plotly as py
import plotly.graph_objs as go

from plotly import tools
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True) 

import numpy as np
import matplotlib.pyplot as plt
# include if using a Jupyter notebook
# %matplotlib inline
dfg = df
dfg
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#    benchmark     k8senv  sbatch  numctn cscenario  cbatch  reps         qps  \
# 0     resnet       none      32       1   offline       1    10  105.314230
# 1     resnet       none      32       2   offline       1    10  137.215083
# 2     resnet       none      32       4   offline       1    10  141.234295
# 3     resnet       none      32       8   offline       1    10  141.248409
# 4     resnet       none      32      16   offline       1    10  139.382784
# 5     resnet       none      32      32   offline       1    10  166.228599
# 6     resnet  cpumemory      32       1   offline       1    10  104.417826
# 7     resnet  cpumemory      32       2   offline       1    10  154.386840
# 8     resnet  cpumemory      32       4   offline       1    10  157.653480
# 9     resnet  cpumemory      32       8   offline       1    10  160.512186
# 10    resnet  cpumemory      32      16   offline       1    10  171.088896
# 11    resnet  cpumemory      32      32   offline       1    10  170.827516
# 12    resnet     cpumem      32       1   offline       1    10  104.267840
# 13    resnet     cpumem      32       2   offline       1    10  152.260298
# 14    resnet     cpumem      32       4   offline       1    10  156.600025
# 15    resnet     cpumem      32       8   offline       1    10  159.546934
# 16    resnet     cpumem      32      16   offline       1    10  173.289853
# 17    resnet     cpumem      32      32   offline       1    10  170.596558
#
#          mean        p50        p80        p90        p95        p99  \
# 0   33.892380  33.883744  53.844176  60.709598  64.150449  67.037034
# 1   18.650120  18.800309  27.669836  30.665241  32.189566  33.991337
# 2   16.715752  16.699866  25.471223  28.125930  29.463639  30.905943
# 3   16.735231  16.996240  24.861762  27.755312  29.215132  30.567862
# 4   16.578870  16.798297  24.766076  27.574967  29.119341  30.648233
# 5    7.559537   7.476931  11.350841  12.740466  13.471654  14.299118
# 6   34.439289  34.200061  54.963355  62.020783  65.482086  68.237573
# 7   10.897323  10.714230  17.300578  19.534565  20.762433  22.066468
# 8    9.792151   9.667257  15.343762  17.417739  18.364562  19.747968
# 9    9.296860   9.153658  14.653031  16.466113  17.378397  18.446181
# 10   5.809908   5.633830   9.062430  10.143009  10.695992  11.980488
# 11   5.528733   5.322416   8.503935   9.636666  10.362251  11.367728
# 12  34.672517  34.704552  55.256647  62.079133  65.504186  68.433219
# 13  11.370946  11.073951  18.339655  20.711909  21.908070  23.328431
# 14   9.812778   9.613919  15.554394  17.511612  18.767894  20.387179
# 15   9.426749   9.208825  14.775753  16.503466  17.444959  18.800198
# 16   5.776178   5.643711   8.853575   9.944991  10.569055  11.465693
# 17   5.453176   5.241977   8.269992   9.635591  10.330012  11.437993
#
#          p999
# 0   67.582270
# 1   34.563036
# 2   31.838715
# 3   32.607023
# 4   33.347896
# 5   15.278524
# 6   69.002127
# 7   22.558320
# 8   20.825648
# 9   19.872408
# 10  12.702491
# 11  13.053457
# 12  69.201165
# 13  23.919168
# 14  21.606343
# 15  19.860025
# 16  12.445329
# 17  13.267180

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from svglib.svglib import svg2rlg
from reportlab.graphics import renderPDF
from reportlab.pdfgen import canvas

from numpy import percentile, mean, std
import plotly.graph_objects as go

from plotly.offline import init_notebook_mode, iplot

import plotly.io as pio
pio.templates.default = "none"
# pio.templates.default = "simple_white"

import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd
# import plotly.express as px

for x in ['qps','mean','p99']:
    for cbatch in [1]:
        for model_name in ['resnet']:
            list_traces = []
            for numctn in [1,2,4,8,16,32]: 
                dfg_bench = dfg[(dfg['benchmark']== model_name)  & (dfg['cbatch']==cbatch) & (dfg['numctn']==numctn) &\
                            ((dfg['k8senv']=='none') |\
                             (dfg['k8senv']=='cpumem')| (dfg['k8senv']=='cpumemory'))]
#                 print(dfg_bench)


                #data
                trace = go.Scatter(
                    name="ctn"+str(numctn),
                    x=[ 'none','cpumem','cpu'],
                    y= dfg_bench[x].values.tolist(),
        #             error_y = dict(type='data', array=df1_bench['model_time_std'].values.tolist()),
                    opacity=0.7,
                    mode='markers'
                )
                list_traces.append(trace)



            #layout
            layout = go.Layout(
                title={
                    'text': "exp18(cpu32)= inter16,intra32 -> inter1,intra2; restapi=32" ,
                    'y':0.85,
                    'x':0.5,
                    'xanchor': 'center',
                    'yanchor': 'top'},
                width=1000,
                height=460,
                xaxis=dict(
                    title= "scenarios",
                    tickvals=[ 'none','cpumem','cpu'],
                    titlefont=dict(
                        size=10,
                        color='rgb(107, 107, 107)'
                    ),
                    tickfont=dict(
                        size=10,
                        color='rgb(107, 107, 107)'
                    )
                ),
                yaxis=dict(
                    title= x+"batch"+str(cbatch),
                    automargin=True,
                    titlefont=dict(
                        size=25,
                        color='rgb(107, 107, 107)'
                    ),
                    tickfont=dict(
                        size=25,
                        color='rgb(107, 107, 107)'
                    ),    
                ),
                legend=dict(
                    x=1.0,
                    y=1.0,
                    bgcolor='rgba(255, 255, 255, 0)',
                    bordercolor='rgba(255, 255, 255, 0)',
                    font = dict( size = 28)
                ),
                barmode='group',
                bargap=0.15,
                bargroupgap=0.08
        #         legend_orientation="h"
            )

        data = list_traces
        fig = go.Figure(data=data, layout=layout)
        fig.update_layout(legend_orientation="h")
        fig.show()    

    #     fig.write_image(path + model_name + k8senv +'.pdf')
# Out:
# <div>                            <div id="4d71b1e9-f432-49c4-a82e-bd028a49e33c" class="plotly-graph-div" style="height:460px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d71b1e9-f432-49c4-a82e-bd028a49e33c")) {                    Plotly.newPlot(                        "4d71b1e9-f432-49c4-a82e-bd028a49e33c",                        [{"mode": "markers", "name": "ctn1", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [105.31423039184251, 104.41782622576034, 104.26783972361608]}, {"mode": "markers", "name": "ctn2", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [137.21508265999947, 154.38684029614183, 152.26029784568408]}, {"mode": "markers", "name": "ctn4", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [141.23429540088935, 157.6534795735717, 156.60002483166326]}, {"mode": "markers", "name": "ctn8", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [141.2484093867549, 160.512185707818, 159.54693435756784]}, {"mode": "markers", "name": "ctn16", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [139.38278447716826, 171.08889571974169, 173.2898526225532]}, {"mode": "markers", "name": "ctn32", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [166.2285993482113, 170.82751580547065, 170.59655797866728]}],                        {"bargap": 0.15, "bargroupgap": 0.08, "barmode": "group", "height": 460, "legend": {"bgcolor": "rgba(255, 255, 255, 0)", "bordercolor": "rgba(255, 255, 255, 0)", "font": {"size": 28}, "orientation": "h", "x": 1.0, "y": 1.0}, "template": {"data": {"scatter": [{"type": "scatter"}]}}, "title": {"text": "exp18(cpu32)= inter16,intra32 -> inter1,intra2; restapi=32", "x": 0.5, "xanchor": "center", "y": 0.85, "yanchor": "top"}, "width": 1000, "xaxis": {"tickfont": {"color": "rgb(107, 107, 107)", "size": 10}, "tickvals": ["none", "cpumem", "cpu"], "title": {"font": {"color": "rgb(107, 107, 107)", "size": 10}, "text": "scenarios"}}, "yaxis": {"automargin": true, "tickfont": {"color": "rgb(107, 107, 107)", "size": 25}, "title": {"font": {"color": "rgb(107, 107, 107)", "size": 25}, "text": "qpsbatch1"}}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('4d71b1e9-f432-49c4-a82e-bd028a49e33c');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>
# <div>                            <div id="f247370e-c154-40d3-9a92-3d01db2d36e3" class="plotly-graph-div" style="height:460px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f247370e-c154-40d3-9a92-3d01db2d36e3")) {                    Plotly.newPlot(                        "f247370e-c154-40d3-9a92-3d01db2d36e3",                        [{"mode": "markers", "name": "ctn1", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [33.89237970522527, 34.43928949005267, 34.67251686244781]}, {"mode": "markers", "name": "ctn2", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [18.650119777638068, 10.897323153455734, 11.370945718966134]}, {"mode": "markers", "name": "ctn4", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [16.715752412294535, 9.792150998406267, 9.812778373247532]}, {"mode": "markers", "name": "ctn8", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [16.735230909659265, 9.296859993415469, 9.426748976142733]}, {"mode": "markers", "name": "ctn16", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [16.578870111619, 5.8099082107522, 5.7761782060414]}, {"mode": "markers", "name": "ctn32", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [7.5595372214266, 5.528733002219734, 5.4531757786418]}],                        {"bargap": 0.15, "bargroupgap": 0.08, "barmode": "group", "height": 460, "legend": {"bgcolor": "rgba(255, 255, 255, 0)", "bordercolor": "rgba(255, 255, 255, 0)", "font": {"size": 28}, "orientation": "h", "x": 1.0, "y": 1.0}, "template": {"data": {"scatter": [{"type": "scatter"}]}}, "title": {"text": "exp18(cpu32)= inter16,intra32 -> inter1,intra2; restapi=32", "x": 0.5, "xanchor": "center", "y": 0.85, "yanchor": "top"}, "width": 1000, "xaxis": {"tickfont": {"color": "rgb(107, 107, 107)", "size": 10}, "tickvals": ["none", "cpumem", "cpu"], "title": {"font": {"color": "rgb(107, 107, 107)", "size": 10}, "text": "scenarios"}}, "yaxis": {"automargin": true, "tickfont": {"color": "rgb(107, 107, 107)", "size": 25}, "title": {"font": {"color": "rgb(107, 107, 107)", "size": 25}, "text": "meanbatch1"}}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('f247370e-c154-40d3-9a92-3d01db2d36e3');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>
# <div>                            <div id="a89a55f8-3b76-498a-ad77-b1278cdca4f4" class="plotly-graph-div" style="height:460px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a89a55f8-3b76-498a-ad77-b1278cdca4f4")) {                    Plotly.newPlot(                        "a89a55f8-3b76-498a-ad77-b1278cdca4f4",                        [{"mode": "markers", "name": "ctn1", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [67.03703372180001, 68.23757256750001, 68.43321940531999]}, {"mode": "markers", "name": "ctn2", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [33.99133650989, 22.06646790068, 23.328431060400003]}, {"mode": "markers", "name": "ctn4", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [30.90594300615, 19.74796803458, 20.3871786196]}, {"mode": "markers", "name": "ctn8", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [30.56786157637, 18.44618107504, 18.80019827223]}, {"mode": "markers", "name": "ctn16", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [30.64823288275, 11.98048839208, 11.46569320735]}, {"mode": "markers", "name": "ctn32", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [14.29911794782, 11.36772844269, 11.43799271391]}],                        {"bargap": 0.15, "bargroupgap": 0.08, "barmode": "group", "height": 460, "legend": {"bgcolor": "rgba(255, 255, 255, 0)", "bordercolor": "rgba(255, 255, 255, 0)", "font": {"size": 28}, "orientation": "h", "x": 1.0, "y": 1.0}, "template": {"data": {"scatter": [{"type": "scatter"}]}}, "title": {"text": "exp18(cpu32)= inter16,intra32 -> inter1,intra2; restapi=32", "x": 0.5, "xanchor": "center", "y": 0.85, "yanchor": "top"}, "width": 1000, "xaxis": {"tickfont": {"color": "rgb(107, 107, 107)", "size": 10}, "tickvals": ["none", "cpumem", "cpu"], "title": {"font": {"color": "rgb(107, 107, 107)", "size": 10}, "text": "scenarios"}}, "yaxis": {"automargin": true, "tickfont": {"color": "rgb(107, 107, 107)", "size": 25}, "title": {"font": {"color": "rgb(107, 107, 107)", "size": 25}, "text": "p99batch1"}}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('a89a55f8-3b76-498a-ad77-b1278cdca4f4');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
# df1 = df[df["name"].isin(["Sample"])]
# df1.reset_index(drop=True,inplace=True)
# ax = df1['issue_to_done'].plot(figsize=figsize)
# ax.set(xlim=(0, 25000))
# ax.set_title('issue start time (usec)');

# %%
# df1['issue_start_ns'].sort_values

# %%
# df_time=df1['issue_start_ns'].shift()
# df_time
# df_time.dtype

# %%
#time poisson
# ax = df_time.plot(figsize=figsize)
# ax.set(xlim=(0, 10000))
# ax.set_title('issue start time (usec)');

# %%
# color=["blue","green","yellow","red","orange","grey"]
# x=0
# for add in ['none-resnet-1-32-S-1-10','none-resnet-2-32-S-1-10'
#             ,'none-resnet-4-32-S-1-10',
#            'none-resnet-8-32-S-1-10','none-resnet-16-32-S-1-10','none-resnet-32-32-S-1-10']:
#     df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/"+add+"/mlperf_log_trace.json")
#     df1 = df[df["name"].isin(["IssueQuery"])]
#     print(max(df1['dur']))
# #     df1['delta'] = df1['ts'].diff()
# #     plt.hist(df1['dur'], 50, density=True, facecolor='g', alpha=0.75)
#     ax = df1['dur'].plot.hist(bins=HIST_BINS, alpha=0.5, figsize=figsize, fc=color[x])
#     ax.set_title('IssueQuery duration (usec)');
#     x = x+1
#     plt.show()

# %%
# df1 = df[df["name"].isin(["IssueQuery"])]
# df1['delta'] = df1['ts'].diff()
# ax = df1['dur'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
# print(max(df1['dur']))
# ax.set_title('IssueQuery duration (usec)');
# # ax.set(xlim=(0, 80000))
# plt.show()
# ax = df1['delta'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
# ax.set_title('Time between IssueQuery (usec)');

# # df1['delta'].describe()

# %%
# for SingleStream
# if True:
#     df1 = df[df["name"].isin(["QuerySamplesComplete"])]
#     ax = df1['dur'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
#     ax.set_title('Inference time (usec)');
#     plt.show()
#     ax = df1['dur'].plot(figsize=figsize)
#     ax.set(ylim=(0, 600))
#     ax.set_title('Individual inference time (usec)');

# %%
BINS=12
color=["blue","green","yellow","red","orange","grey"]

for sc in ['none','cpumem','cpumemory']:
    print(sc)
    SCEN=[sc+'-resnet-1-32-S-1-10',
          sc+'-resnet-2-32-S-1-10',
             sc+'-resnet-4-32-S-1-10',
               sc+'-resnet-8-32-S-1-10',
          sc+'-resnet-16-32-S-1-10',
          sc+'-resnet-32-32-S-1-10']
    x=0
    for add in SCEN:
        df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/"+add+"/mlperf_log_trace.json")
        df1 = df[df["name"].isin(["Sample"])]
        print(max(df1['issue_to_done'])/ 1e6)
        print(np.median(df1['issue_to_done'])/ 1e6)
        print(np.mean(df1['issue_to_done'])/ 1e6)
    #     ax = df1['issue_to_done'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
    #     ax.set_title('Inference time (usec)');
    #     x = x+1
    #     plt.show()

        # Draw the density plot
        sns.distplot(df1['issue_to_done'] / 1e6, hist = False, kde = True,
                     kde_kws = {'linewidth': 3},
                     label = SCEN[x])
        x=x+1

    # Plot formatting
    plt.legend(prop={'size': 16}, title = 'SCENARIO',loc='center left', bbox_to_anchor=(1, 0.5) )
    plt.title('Inference time')
    plt.xlabel('time (sec)')
    plt.ylabel('Density')
    plt.show()
# Out:
# none
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/none-resnet-1-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 12.808673074
# 12.106108776000001
# 11.108982769734668
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/none-resnet-2-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 12.008693276
# 8.656257436999999
# 8.340344883225043
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/none-resnet-4-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 12.48558375
# 8.2515030825
# 8.055380796852852
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/none-resnet-8-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 13.80733359
# 8.3894321965
# 8.050314839534993
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/none-resnet-16-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 14.173155078
# 8.321807199
# 8.033044036859133
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/none-resnet-32-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 9.641507812999999
# 6.666214901000001
# 5.986334578299334
# cpumem
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumem-resnet-1-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 13.107852839
# 12.241979291499998
# 11.235624765378223
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumem-resnet-2-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 10.836761707
# 7.2308819215
# 6.93714741070434
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumem-resnet-4-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 11.893978748
# 7.296536313999999
# 6.556801200853305
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumem-resnet-8-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 12.576263892
# 7.112322032
# 6.448263723647867
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumem-resnet-16-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 10.403378222999999
# 5.643215095
# 5.168908985584069
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumem-resnet-32-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 10.952698184
# 5.2411632885
# 5.025179885502867
# cpumemory
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumemory-resnet-1-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 14.609470792
# 12.172677031500001
# 11.220453076470317
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumemory-resnet-2-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 10.595446287
# 7.3392504705
# 6.817725638090909
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumemory-resnet-4-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 11.807228913000001
# 7.4980257565
# 6.553575672781355
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumemory-resnet-8-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 12.136597376000001
# 7.058384321499999
# 6.401748603897584
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumemory-resnet-16-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 10.287379475
# 5.6328998205000005
# 5.180857594566965
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumemory-resnet-32-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 10.710725114
# 5.3215124505
# 5.052888725280474

# %%
BINS=12
color=["blue","green","yellow","red","orange","grey"]

for sc in ['none','cpumem','cpumemory']:
    print(sc)
    SCEN=[sc+'-resnet-1-32-S-1-10',
          sc+'-resnet-2-32-S-1-10',
             sc+'-resnet-4-32-S-1-10',
               sc+'-resnet-8-32-S-1-10',
          sc+'-resnet-16-32-S-1-10',
          sc+'-resnet-32-32-S-1-10']
    x=0
    for add in SCEN:
        df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/"+add+"/mlperf_log_trace.json")
        df1 = df[df["name"].isin(["Latency"])]
        print(max(df1['issue_delay'])/ 1e6)
        print(np.median(df1['issue_delay'])/ 1e6)
        print(np.mean(df1['issue_delay'])/ 1e6)
    #     ax = df1['issue_to_done'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
    #     ax.set_title('Inference time (usec)');
    #     x = x+1
    #     plt.show()

        # Draw the density plot
        sns.distplot(df1['issue_delay'] / 1e6, hist = False, kde = True,
                     kde_kws = {'linewidth': 3},
                     label = SCEN[x])
        x=x+1

    # Plot formatting
    plt.legend(prop={'size': 16}, title = 'SCENARIO',loc='center left', bbox_to_anchor=(1, 0.5) )
    plt.title('Inference time')
    plt.xlabel('time (sec)')
    plt.ylabel('Density')
    plt.show()
# Out:
# none
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/none-resnet-1-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 55.471690772
# 21.7760735185
# 22.78339693549052
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/none-resnet-2-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 24.791389668
# 10.079881597
# 10.30977489441303
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/none-resnet-4-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 22.212400506999998
# 8.0905068325
# 8.660371615441676
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/none-resnet-8-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 21.913097311999998
# 8.36530552
# 8.684916070124263
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/none-resnet-16-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 21.685330067000002
# 8.235880894500001
# 8.545826074759779
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/none-resnet-32-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 6.656712368
# 0.0371768825
# 1.5732026431272654
# cpumem
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumem-resnet-1-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 56.766364226
# 22.3908099845
# 23.436892097069578
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumem-resnet-2-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 14.753496593
# 2.9333371280000002
# 4.4337983082618
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumem-resnet-4-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 11.600630186
# 1.7493882365000002
# 3.2559771723942057
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumem-resnet-8-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 10.491974314
# 1.5325145665000002
# 2.97848525249486
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumem-resnet-16-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 3.770413698
# 0.001316956
# 0.6072692204573331
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumem-resnet-32-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 3.4689646979999997
# 0.0005779435
# 0.42799589313893327
# cpumemory
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumemory-resnet-1-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 56.707493527000004
# 21.948944367
# 23.218836413582412
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumemory-resnet-2-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 13.613874831
# 2.6068721805
# 4.079597515364791
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumemory-resnet-4-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 11.422119465
# 1.764519068
# 3.2385753256249354
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumemory-resnet-8-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 10.439607449999999
# 1.3699403025
# 2.895111389517871
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumemory-resnet-16-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 4.025116083
# 0.0010177265
# 0.6290506161852657
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumemory-resnet-32-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 3.5126071430000003
# 0.0006955879999999999
# 0.4758442769392659

# %%
BINS=12
color=["blue","green","yellow","red","orange","grey"]
for sc in ['none','cpumem','cpumemory']:
    print(sc)
    SCEN=[sc+'-resnet-1-32-S-1-10',
#           sc+'-resnet-2-32-S-1-10',
#              sc+'-resnet-4-32-S-1-10',
#                sc+'-resnet-8-32-S-1-10',
#           sc+'-resnet-16-32-S-1-10',
          sc+'-resnet-32-32-S-1-10']
    x=0
    for add in SCEN:
        df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/"+add+"/mlperf_log_trace.json")
        df1 = df[df["name"].isin(["Latency"])]
        df1.reset_index(drop=True,inplace=True)
        ax = df1['issue_delay'].plot(figsize=figsize, color=color[x])
        ax = df1['issue_to_done'].plot(figsize=figsize, color=color[x])
        ax.set_title('Individual inference time (usec)');
    #     ax.set(ylim=(0, 100))
        x=x+1
    plt.legend(prop={'size': 16}, title = 'SCENARIO',loc='center left', bbox_to_anchor=(1, 0.5) )
    plt.show()
# Out:
# none
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/none-resnet-1-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/none-resnet-32-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# cpumem
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumem-resnet-1-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumem-resnet-32-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# cpumemory
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumemory-resnet-1-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp23/cpumemory-resnet-32-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>

# %%
# df1 = df[df["name"].isin(["Latency"])]
# ax = df1['issue_to_done'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
# ax.set_title('Inference time (usec)');
# #ax.set(xlim=(0, 25000))
# plt.xticks(rotation=60)
# plt.show()

# ax = df1['issue_to_done'].plot(figsize=figsize)
# ax.set_title('Individual inference time (usec)');
# #ax.set(ylim=(0, 200))
# plt.show()


# # df1['issue_to_done'].describe()

# %%
# df1 = df[df["name"].isin(["QuerySamplesComplete"])]
# df1['delta'] = df1['ts'].diff()
# ax = df1['delta'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
# ax.set_title('Time between QuerySamplesComplete (usec)');
# plt.show()

# ax = df1['dur'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
# ax.set_title('Time QuerySamplesComplete (usec)');

# %% [markdown]
# # offline scenario

# %%
BINS=12
color=["blue","green","yellow","red","orange","grey"]
SCEN=[
    'none-resnet-1-32-O-1-10',
      'none-resnet-2-32-O-1-10',
            'none-resnet-4-32-O-1-10',
           'none-resnet-8-32-O-1-10',
      'none-resnet-16-32-O-1-10',
      'none-resnet-32-32-O-1-10'
]
x=0
for add in SCEN:
    df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/"+add+"/mlperf_log_trace.json")
    df1 = df[df["name"].isin(["IssueQuery"])]
    print(df1)
#     ax = df1['dur'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
#     ax.set_title('IssueQuery duration (usec)');
#     x=x+1
#     plt.show()

# df1['delta'].describe()
# Out:
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/none-resnet-1-32-O-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
#                ts        name           dur  issue_start_ns  complete_ns  \
# 46592  167409.695  IssueQuery  2.226891e+08             NaN          NaN
#
#        issue_to_done
# 46592            NaN
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/none-resnet-2-32-O-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
#                ts        name           dur  issue_start_ns  complete_ns  \
# 46594  182404.083  IssueQuery  1.674079e+08             NaN          NaN
#
#        issue_to_done
# 46594            NaN
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/none-resnet-4-32-O-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
#                ts        name           dur  issue_start_ns  complete_ns  \
# 46592  190387.264  IssueQuery  1.610120e+08             NaN          NaN
#
#        issue_to_done
# 46592            NaN
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/none-resnet-8-32-O-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
#                ts        name           dur  issue_start_ns  complete_ns  \
# 46592  186998.126  IssueQuery  1.611064e+08             NaN          NaN
#
#        issue_to_done
# 46592            NaN
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/none-resnet-16-32-O-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
#                ts        name           dur  issue_start_ns  complete_ns  \
# 46592  181077.299  IssueQuery  1.577625e+08             NaN          NaN
#
#        issue_to_done
# 46592            NaN
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/none-resnet-32-32-O-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
#               ts        name           dur  issue_start_ns  complete_ns  \
# 46592  185902.34  IssueQuery  1.388344e+08             NaN          NaN
#
#        issue_to_done
# 46592            NaN

# %%
# # for SingleStream
# if True:
#     df1 = df[df["name"].isin(["QuerySamplesComplete"])]
#     ax = df1['dur'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
#     ax.set_title('Inference time (usec)');
#     plt.show()
#     ax = df1['dur'].plot(figsize=figsize)
#     ax.set(ylim=(0, 600))
#     ax.set_title('Individual inference time (usec)');

# %%
BINS=12
color=["blue","green","yellow","red","orange","grey"]
for batch in ['32']:
    SCEN=[
        'none-resnet-1-32-O-'+batch+'-10',
          'none-resnet-2-32-O-'+batch+'-10',
                'none-resnet-4-32-O-'+batch+'-10',
               'none-resnet-8-32-O-'+batch+'-10',
          'none-resnet-16-32-O-'+batch+'-10',
          'none-resnet-32-32-O-'+batch+'-10'
    ]
    x=0
    for add in SCEN:
        df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/"+add+"/mlperf_log_trace.json")
        df1 = df[df["name"].isin(["QuerySamplesComplete"])]
        print(max(df1['dur']))
        print(np.median(df1['dur']))
        print(np.mean(df1['dur']))
    #     ax = df1['issue_to_done'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
    #     ax.set_title('Inference time (usec)');
    #     x = x+1
    #     plt.show()

        # Draw the density plot
        sns.distplot(df1['dur'], hist = False, kde = True,
                     kde_kws = {'linewidth': 3},
                     label = SCEN[x])
        x=x+1

    # Plot formatting
    plt.legend(prop={'size': 16}, title = 'SCENARIO',loc='center left', bbox_to_anchor=(1, 0.5) )
    plt.title('Inference time (usec) -- batch'+str(batch))
    plt.xlabel('time (usec)')
    plt.ylabel('Density')
    plt.show()
# Out:
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/none-resnet-1-32-O-32-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 127.833
# 10.5115
# 12.462266927083325
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/none-resnet-2-32-O-32-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 84.815
# 10.3185
# 10.782372395833333
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/none-resnet-4-32-O-32-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 114.674
# 10.498000000000001
# 12.094303385416675
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/none-resnet-8-32-O-32-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 124.038
# 10.9745
# 12.852624999999998
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/none-resnet-16-32-O-32-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 122.052
# 10.313500000000001
# 12.18345052083334
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/none-resnet-32-32-O-32-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 120.43
# 10.7135
# 12.092220052083327

# %%
BINS=12
color=["blue","green","yellow","red","orange","grey"]
for batch in ['32']:
    SCEN=[
        'none-resnet-1-32-O-'+batch+'-10',
          'none-resnet-2-32-O-'+batch+'-10',
                'none-resnet-4-32-O-'+batch+'-10',
               'none-resnet-8-32-O-'+batch+'-10',
          'none-resnet-16-32-O-'+batch+'-10',
          'none-resnet-32-32-O-'+batch+'-10'
    ]
    x=0
    for add in SCEN:
        df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/"+add+"/mlperf_log_trace.json")
        df1 = df[df["name"].isin(["QuerySamplesComplete"])]
        df1.reset_index(drop=True,inplace=True)
        ax = df1['dur'].plot(figsize=figsize, color=color[x],label = SCEN[x])
        ax.set_title('Individual inference time (usec)');
        ax.set(ylim=(0, 150))
        x=x+1
    plt.legend(prop={'size': 16}, title = 'SCENARIO',loc='center left', bbox_to_anchor=(1, 0.5) )
    plt.show()
    plt.xlabel('#QuerySamples')
# Out:
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/none-resnet-1-32-O-32-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/none-resnet-2-32-O-32-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/none-resnet-4-32-O-32-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/none-resnet-8-32-O-32-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/none-resnet-16-32-O-32-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/none-resnet-32-32-O-32-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>

# %%
df1 = df[df["name"].isin(["QuerySamplesComplete"])]
ax = df1['dur'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
ax.set_title('Inference time (usec)');
#ax.set(xlim=(0, 25000))
plt.xticks(rotation=60)
plt.show()

ax = df1['dur'].plot(figsize=figsize)
ax.set_title('Individual inference time (usec)');
#ax.set(ylim=(0, 200))
plt.show()


# df1['issue_to_done'].describe()

# %%
df1 = df[df["name"].isin(["QuerySamplesComplete"])]
df1['delta'] = df1['ts'].diff()
ax = df1['delta'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
ax.set_title('Time between QuerySamplesComplete (usec)');
plt.show()

ax = df1['dur'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
ax.set_title('Time QuerySamplesComplete (usec)');
