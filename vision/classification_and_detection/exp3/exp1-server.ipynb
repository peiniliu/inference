# %% [markdown]
# # Tool to extract usefull information from mlperf trace

# %%
# %matplotlib inline
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

import json
import os
import seaborn as sns
from operator import itemgetter
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

figsize=(10, 5)
font=10

plt.figure(dpi=600)
plt.rc('xtick', labelsize=font) 
plt.rc('font', size=font)
sns.set(font_scale=1.4, style="whitegrid");

# %%
def trace_to_df(fname):
    with open(fname, "r") as f:
        print(f)
        j = json.load(f)
    if type(j) == dict:
        j = j['traceEvents']
        
    result = []
    for item in j:
        name = item['name']
        if name not in ["Latency", "Sample", "QuerySamplesComplete", "IssueQuery"]:
            continue

        args = item.get('args')
        d = {"ts": item['ts'], "name": name, "dur": item.get("dur")}

        if name == "Latency":
            d["issue_delay"] = args["issue_delay"] /1e9
            d["issue_to_done"] = args["issue_to_done"] / 1e9
            result.append(d)
        elif name == "Sample":
            if args:
                d["issue_start_ns"] = args["issue_start_ns"]
                d["complete_ns"] = args["complete_ns"]
                d["issue_to_done"] = (args["complete_ns"] - args["issue_start_ns"]) / 1e9
                result.append(d)
        elif name == "QuerySamplesComplete":
            result.append(d)
        elif name == "IssueQuery":
            result.append(d)

    df = pd.DataFrame(result)
    df = df.sort_values(by=["ts"])
    return df

BINS = 10

# %%
# Fixing bin edges
HIST_BINS = np.linspace(0, 1000000, 100)

# %%
df = trace_to_df('/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/none-resnet-1-32-S-1-10/mlperf_log_trace.json')
df.describe()
# Out:
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/output-exp22/none-resnet-1-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
#                  ts           dur   issue_delay  issue_to_done  \
# count  4.802000e+04  24010.000000  1.200500e+04   24010.000000
# mean   4.133834e+07   3873.221525  1.697624e+01      11.016417
# std    2.852758e+07   7212.683331  1.416478e+01       2.908724
# min    1.960050e+05      3.011000  2.220000e-07       0.146377
# 25%    1.781401e+07      6.087000  2.188979e+00      12.145755
# 50%    3.751535e+07     45.319500  1.575882e+01      12.261240
# 75%    5.730396e+07   5077.102750  2.938598e+01      12.307844
# max    1.156422e+08  85201.312000  4.319503e+01      13.140706
#
#        issue_start_ns   complete_ns
# count    1.200500e+04  1.200500e+04
# mean     1.697624e+10  2.799266e+10
# std      1.416478e+10  1.591214e+10
# min      2.220000e+02  1.463859e+08
# 25%      2.188979e+09  1.435780e+10
# 50%      1.575882e+10  2.800297e+10
# 75%      2.938598e+10  4.166818e+10
# max      4.319503e+10  5.553629e+10

# %%
df["name"].unique()
# Out:
# array(['Sample', 'Latency', 'IssueQuery', 'QuerySamplesComplete'],
#       dtype=object)

# %%
df
# Out:
#                  ts                  name      dur  issue_delay  \
# 32     1.960050e+05                Sample      NaN          NaN
# 31     1.960050e+05               Latency      NaN     0.000009
# 0      1.960152e+05            IssueQuery  117.724          NaN
# 42     2.132605e+05                Sample      NaN          NaN
# 41     2.132605e+05               Latency      NaN     0.000089
# ...             ...                   ...      ...          ...
# 48007  1.156336e+08  QuerySamplesComplete    5.511          NaN
# 48010  1.156343e+08  QuerySamplesComplete    5.612          NaN
# 48013  1.156369e+08  QuerySamplesComplete    6.510          NaN
# 48016  1.156420e+08  QuerySamplesComplete   10.615          NaN
# 48019  1.156422e+08  QuerySamplesComplete    5.915          NaN
#
#        issue_to_done  issue_start_ns  complete_ns
# 32          0.146377          8660.0  146385940.0
# 31          0.146377             NaN          NaN
# 0                NaN             NaN          NaN
# 42          0.158766         88964.0  158854679.0
# 41          0.158766             NaN          NaN
# ...              ...             ...          ...
# 48007            NaN             NaN          NaN
# 48010            NaN             NaN          NaN
# 48013            NaN             NaN          NaN
# 48016            NaN             NaN          NaN
# 48019            NaN             NaN          NaN
#
# [48020 rows x 7 columns]

# %%
df1 = df[df["name"].isin(["Sample"])]
df1
# Out:
#                  ts    name  dur  issue_delay  issue_to_done  issue_start_ns  \
# 32     1.960050e+05  Sample  NaN          NaN       0.146377    8.660000e+03
# 42     2.132605e+05  Sample  NaN          NaN       0.158766    8.896400e+04
# 49     2.151299e+05  Sample  NaN          NaN       0.180541    6.118800e+04
# 56     2.222754e+05  Sample  NaN          NaN       0.205071    8.422600e+04
# 71     2.367617e+05  Sample  NaN          NaN       0.238382    1.121140e+05
# ...             ...     ...  ...          ...            ...             ...
# 48006  6.018522e+07  Sample  NaN          NaN      12.264782    4.318361e+10
# 48009  6.019079e+07  Sample  NaN          NaN      12.255490    4.318802e+10
# 48012  6.019285e+07  Sample  NaN          NaN      12.249021    4.319503e+10
# 48018  6.019572e+07  Sample  NaN          NaN      12.254237    4.319224e+10
# 48015  6.019789e+07  Sample  NaN          NaN      12.250183    4.319395e+10
#
#         complete_ns
# 32     1.463859e+08
# 42     1.588547e+08
# 49     1.806019e+08
# 56     2.051549e+08
# 71     2.384945e+08
# ...             ...
# 48006  5.544839e+10
# 48009  5.544351e+10
# 48012  5.544405e+10
# 48018  5.544648e+10
# 48015  5.544414e+10
#
# [12005 rows x 7 columns]

# %%
df1 = df[df["name"].isin(["IssueQuery"])]
df1
# Out:
#                  ts        name       dur  issue_delay  issue_to_done  \
# 0      1.960152e+05  IssueQuery   117.724          NaN            NaN
# 1      2.133538e+05  IssueQuery    73.206          NaN            NaN
# 2      2.151961e+05  IssueQuery  1279.242          NaN            NaN
# 3      2.223629e+05  IssueQuery    63.277          NaN            NaN
# 4      2.368800e+05  IssueQuery   114.567          NaN            NaN
# ...             ...         ...       ...          ...            ...
# 44163  1.033688e+08  IssueQuery  9974.363          NaN            NaN
# 44170  1.033788e+08  IssueQuery  9063.663          NaN            NaN
# 44171  1.033879e+08  IssueQuery    79.233          NaN            NaN
# 44181  1.033880e+08  IssueQuery  3874.435          NaN            NaN
# 44182  1.033918e+08  IssueQuery  5538.585          NaN            NaN
#
#        issue_start_ns  complete_ns
# 0                 NaN          NaN
# 1                 NaN          NaN
# 2                 NaN          NaN
# 3                 NaN          NaN
# 4                 NaN          NaN
# ...               ...          ...
# 44163             NaN          NaN
# 44170             NaN          NaN
# 44171             NaN          NaN
# 44181             NaN          NaN
# 44182             NaN          NaN
#
# [12005 rows x 7 columns]

# %%
df1 = df[df["name"].isin(["Latency"])]
df1
# Out:
#                  ts     name  dur  issue_delay  issue_to_done  issue_start_ns  \
# 31     1.960050e+05  Latency  NaN     0.000009       0.146377             NaN
# 41     2.132605e+05  Latency  NaN     0.000089       0.158766             NaN
# 48     2.151299e+05  Latency  NaN     0.000061       0.180541             NaN
# 55     2.222754e+05  Latency  NaN     0.000084       0.205071             NaN
# 70     2.367617e+05  Latency  NaN     0.000112       0.238382             NaN
# ...             ...      ...  ...          ...            ...             ...
# 48005  6.018522e+07  Latency  NaN    43.183610      12.264782             NaN
# 48008  6.019079e+07  Latency  NaN    43.188023      12.255490             NaN
# 48011  6.019285e+07  Latency  NaN    43.195032      12.249021             NaN
# 48017  6.019572e+07  Latency  NaN    43.192240      12.254237             NaN
# 48014  6.019789e+07  Latency  NaN    43.193955      12.250183             NaN
#
#        complete_ns
# 31             NaN
# 41             NaN
# 48             NaN
# 55             NaN
# 70             NaN
# ...            ...
# 48005          NaN
# 48008          NaN
# 48011          NaN
# 48017          NaN
# 48014          NaN
#
# [12005 rows x 7 columns]

# %%
df1 = df[df["name"].isin(["QuerySamplesComplete"])]
df1
# Out:
#                  ts                  name     dur  issue_delay  issue_to_done  \
# 33     3.423921e+05  QuerySamplesComplete  26.157          NaN            NaN
# 43     3.721166e+05  QuerySamplesComplete  19.930          NaN            NaN
# 50     3.957332e+05  QuerySamplesComplete  26.923          NaN            NaN
# 57     4.274315e+05  QuerySamplesComplete  21.168          NaN            NaN
# 72     4.752575e+05  QuerySamplesComplete  20.600          NaN            NaN
# ...             ...                   ...     ...          ...            ...
# 48007  1.156336e+08  QuerySamplesComplete   5.511          NaN            NaN
# 48010  1.156343e+08  QuerySamplesComplete   5.612          NaN            NaN
# 48013  1.156369e+08  QuerySamplesComplete   6.510          NaN            NaN
# 48016  1.156420e+08  QuerySamplesComplete  10.615          NaN            NaN
# 48019  1.156422e+08  QuerySamplesComplete   5.915          NaN            NaN
#
#        issue_start_ns  complete_ns
# 33                NaN          NaN
# 43                NaN          NaN
# 50                NaN          NaN
# 57                NaN          NaN
# 72                NaN          NaN
# ...               ...          ...
# 48007             NaN          NaN
# 48010             NaN          NaN
# 48013             NaN          NaN
# 48016             NaN          NaN
# 48019             NaN          NaN
#
# [12005 rows x 7 columns]

# %% [markdown]
# # server scenario

# %%
import pandas as pd
import glob
# import plotly.plotly as py
import plotly.graph_objs as go

from plotly import tools
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True) 

import numpy as np
import matplotlib.pyplot as plt
# include if using a Jupyter notebook
# %matplotlib inline

path = "/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp2/"
all_files = glob.glob(path + "*-s.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True)
df.head()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#   benchmark    k8senv  sbatch  numctn cscenario  cbatch  reps         qps  \
# 0    resnet  baseline      32       1    server       1     1   99.759074
# 1    resnet  baseline      32       1    server       1     2  100.285574
# 2    resnet  baseline      32       1    server       1     3  100.402620
# 3    resnet  baseline      32       1    server       1     4  100.375967
# 4    resnet  baseline      32       1    server       1     5  100.570499
#
#         mean        p50        p80        p90        p95        p99       p999
# 0  32.645211  32.773385  51.721496  58.110764  61.187491  63.980205  67.115089
# 1  32.032450  32.052371  50.999148  57.378747  60.628964  63.208141  64.601013
# 2  32.031588  32.069496  50.898902  57.314305  60.442311  63.116354  65.565186
# 3  32.049939  32.107914  50.959695  57.368215  60.510597  63.214565  64.658783
# 4  31.916317  31.936650  50.784067  57.199632  60.264634  62.873378  64.422924

# %%
import pandas as pd
import glob
# import plotly.plotly as py
import plotly.graph_objs as go

from plotly import tools
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True) 

import numpy as np
import matplotlib.pyplot as plt
# include if using a Jupyter notebook
# %matplotlib inline
dfg = df
dfg
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#     benchmark     k8senv  sbatch  numctn cscenario  cbatch  reps         qps  \
# 0      resnet   baseline      32       1    server       1     1   99.759074
# 1      resnet   baseline      32       1    server       1     2  100.285574
# 2      resnet   baseline      32       1    server       1     3  100.402620
# 3      resnet   baseline      32       1    server       1     4  100.375967
# 4      resnet   baseline      32       1    server       1     5  100.570499
# ..        ...        ...     ...     ...       ...     ...   ...         ...
# 125    resnet  cpumemory      32      32    server       1     6  177.640008
# 126    resnet  cpumemory      32      32    server       1     7  177.998831
# 127    resnet  cpumemory      32      32    server       1     8  178.146853
# 128    resnet  cpumemory      32      32    server       1     9  178.380486
# 129    resnet  cpumemory      32      32    server       1    10  178.646642
#
#           mean        p50        p80        p90        p95        p99  \
# 0    32.645211  32.773385  51.721496  58.110764  61.187491  63.980205
# 1    32.032450  32.052371  50.999148  57.378747  60.628964  63.208141
# 2    32.031588  32.069496  50.898902  57.314305  60.442311  63.116354
# 3    32.049939  32.107914  50.959695  57.368215  60.510597  63.214565
# 4    31.916317  31.936650  50.784067  57.199632  60.264634  62.873378
# ..         ...        ...        ...        ...        ...        ...
# 125   3.082131   2.989978   4.556120   5.574221   6.017098   7.261727
# 126   2.965526   2.855529   4.401012   5.389115   5.762728   7.183265
# 127   3.017887   2.897856   4.490597   5.450929   5.841749   7.249161
# 128   2.964471   2.840899   4.435546   5.414641   5.821636   7.068705
# 129   2.972098   2.845158   4.441052   5.428335   5.823000   7.148667
#
#           p999
# 0    67.115089
# 1    64.601013
# 2    65.565186
# 3    64.658783
# 4    64.422924
# ..         ...
# 125   8.353964
# 126   8.231588
# 127   8.165713
# 128   8.019002
# 129   7.982632
#
# [130 rows x 15 columns]

# %%
# from numpy import percentile, mean, std

# l_gb = ['benchmark', 'cbatch','sbatch','numctn']

# df_results = []

# for model_name in df['benchmark'].unique():
#        df_bench = df[(df['benchmark']==model_name)] # everybenchmark
# #        print(df_bench)
#        for senario in df_bench.cscenario.unique():
#             df_senario = df_bench[df_bench.cscenario == senario]
#             df_senario = df_senario.groupby(l_gb, sort=False).apply(lambda x: pd.Series({
#                   'model_time_mean' : mean(x['qps']),
#                   'model_time_std' : std(x['qps']),
#               })).reset_index()
# #             s1 = pd.Series([model_name,senario,16,'C','CPU',np.nan,np.nan], \
# #                            index=['benchmark','senario','num_process','class','type','model_time_mean','model_time_std'])
# #             s2 = pd.Series([model_name,senario,16,'C','CPUMEM',np.nan,np.nan], \
# #                            index=['benchmark','senario','num_process','class','type','model_time_mean','model_time_std'])
#             df_results.append(df_senario)

# %%
# df_results = pd.concat(df_results, axis=0)
# df_results

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from svglib.svglib import svg2rlg
from reportlab.graphics import renderPDF
from reportlab.pdfgen import canvas

from numpy import percentile, mean, std
import plotly.graph_objects as go

from plotly.offline import init_notebook_mode, iplot

import plotly.io as pio
pio.templates.default = "none"
# pio.templates.default = "simple_white"

import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd
# import plotly.express as px

# import seaborn library
import seaborn as sns
legend=['$SUT_{1}$','$SUT_{2}$','$SUT_{4}$','$SUT_{8}$','$SUT_{16}$','$SUT_{32}$']
ylabel=['Mean Latency','99-th Percentile Latency','Queries Per Second(qps) \n s.t. latency<65s']

label=0
for x in ['mean','p999','qps']:
    for cbatch in [1]:
        for model_name in ['resnet']:
            list_traces = []
            for env in ['baseline','none','cpumemory']:
    #             for numctn in [1,2,4,8,16,32]: 
                dfg_bench = dfg[(dfg['benchmark']== model_name)  & (dfg['cbatch']==cbatch) & \
    #                             (dfg['numctn']==numctn) &\
                            ((dfg['k8senv']==env))]
    #                          |\
    #                          (dfg['k8senv']=='cpumem')| (dfg['k8senv']=='cpumemory'))]
    #                 print(dfg_bench)
                list_traces.append(dfg_bench)
            dfall = pd.concat(list_traces, axis=0, ignore_index=True)
            ax = sns.boxplot(x = dfall['k8senv'],
                        y = dfall[x],
                        hue = dfall['numctn'])
            handles, _ = ax.get_legend_handles_labels()
            ax.legend(handles, legend, prop={'size': 15}, title = '$SUT_{N_{cph}}$',loc='center left', bbox_to_anchor=(1, 0.5))
#             plt.legend(legend,prop={'size': 16}, title = '$SUT_{N_{cph}}$',loc='center left', bbox_to_anchor=(1, 0.5) )
            ax.set_xticklabels(["Baseline","ANY","CPUMEM"])
            plt.xlabel("")
            plt.ylabel(ylabel[label])
            label=label+1
            plt.title("(c) Server")
            plt.savefig('s-metric.pdf',bbox_inches='tight')  
            plt.show()

# %%
#y is the issue_start_ns
# df1 = df[df["name"].isin(["Sample"])]
# df1.reset_index(drop=True,inplace=True)
# ax = df1['issue_start_ns'].plot(figsize=figsize)
# ax.set(xlim=(0, 25000))
# ax.set_title('issue start time (usec)');

# %%
# df1['issue_start_ns'].sort_values

# %%
# df_time=df1['issue_start_ns'].shift()
# df_time
# df_time.dtype

# %%
#time poisson
# ax = df_time.plot(figsize=figsize)
# ax.set(xlim=(0, 10000))
# ax.set_title('issue start time (usec)');

# %%
color=["blue","green","yellow","red","orange","grey"]
x=0
for add in ['none-resnet-1-32-S-1-1','none-resnet-2-32-S-1-1'
            ,'none-resnet-4-32-S-1-1',
           'none-resnet-8-32-S-1-1','none-resnet-16-32-S-1-1','none-resnet-32-32-S-1-1']:
    df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/"+add+"/mlperf_log_trace.json")
    df1 = df[df["name"].isin(["IssueQuery"])]
    print(max(df1['dur']))
    df1['delta'] = df1['ts'].diff()
#     plt.hist(df1['dur'], 50, density=True, facecolor='g', alpha=0.75)
    ax = df1['dur'].plot.hist(bins=HIST_BINS, alpha=0.5, figsize=figsize, fc=color[x])
    ax.set_title('IssueQuery duration (usec)');
    x = x+1
    plt.show()
    
    ax = df1['delta'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
    ax.set_title('Time between IssueQuery (usec)');
    plt.show()
# Out:
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-1-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 129961.871
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-2-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 218056.585
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-4-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 224814.686
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-8-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 196014.074
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-16-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 117204.339
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-32-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 281419.457

# %%
# df1 = df[df["name"].isin(["IssueQuery"])]
# df1['delta'] = df1['ts'].diff()
# ax = df1['dur'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
# print(max(df1['dur']))
# ax.set_title('IssueQuery duration (usec)');
# # ax.set(xlim=(0, 80000))
# plt.show()
# ax = df1['delta'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
# ax.set_title('Time between IssueQuery (usec)');

# # # df1['delta'].describe()
# Out:
# 226919.99

# %%
# for SingleStream
# if True:
#     df1 = df[df["name"].isin(["QuerySamplesComplete"])]
#     ax = df1['dur'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
#     ax.set_title('Inference time (usec)');
#     plt.show()
#     ax = df1['dur'].plot(figsize=figsize)
#     ax.set(ylim=(0, 600))
#     ax.set_title('Individual inference time (usec)');

# %%
BINS=12
color=["black","blue","green","yellow","red","orange","pink"]
legend=['$SUT_{baseline}$','$SUT_{1}$','$SUT_{2}$','$SUT_{4}$','$SUT_{8}$','$SUT_{16}$','$SUT_{32}$']

for sc in ['none','cpumemory']:
    print(sc)
    SCEN=[sc+'-resnet-1-32-S-1-1',
          sc+'-resnet-2-32-S-1-1',
             sc+'-resnet-4-32-S-1-1',
               sc+'-resnet-8-32-S-1-1',
          sc+'-resnet-16-32-S-1-1',
          sc+'-resnet-32-32-S-1-1']
    x=0
#     df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp2-baseline/none-resnet-1-32-S-1-10/mlperf_log_trace.json")
#     df1 = df[df["name"].isin(["Latency"])]
# #     sns.distplot(df1['issue_to_done'], hist = False, kde = True,
# #                      kde_kws = {'linewidth': 3},
# #                      label = legend[x])
#     sns.histplot(df1['issue_to_done'], kde = True,
# #                      kde_kws = {'linewidth': 3},
#                      label = legend[x],color=color[x])
#     x=x+1
    for add in SCEN:
        df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/"+add+"/mlperf_log_trace.json")
        df1 = df[df["name"].isin(["Latency"])]
        print(max(df1['issue_to_done']))
        print(np.median(df1['issue_to_done']))
        print(np.mean(df1['issue_to_done']))
    #     ax = df1['issue_to_done'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
    #     ax.set_title('Inference time (usec)');
    #     x = x+1
    #     plt.show()

        # Draw the density plot
#         sns.distplot(df1['issue_to_done'], hist = False, kde = True,
#                      kde_kws = {'linewidth': 3},
#                      label = legend[x])
        sns.histplot(df1['issue_to_done'], kde = True,
#                      kde_kws = {'linewidth': 3},
                     label = legend[x],color=color[x])
        x=x+1

    # Plot formatting
    plt.legend(prop={'size': 16}, title = '$SUT_{N_{cph}}$',loc='center left', bbox_to_anchor=(1, 0.5) )
#     handles, _ = ax.get_legend_handles_labels()
#     ax.legend(handles, legend, prop={'size': 15}, title = ,loc='center left', bbox_to_anchor=(1, 0.5))
    plt.title('S - Inference time distribution')
    plt.xlabel('Time (sec)')
    plt.ylabel('Density')
    plt.savefig('s-itd'+sc+'.pdf',bbox_inches='tight')  
    plt.show()
# Out:
# none
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-1-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 2.310353777
# 0.23798101
# 0.5101161450643906
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-2-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 2.259437494
# 0.1898958475
# 0.49169637738384897
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-4-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 2.620875081
# 0.2641547295
# 0.5556721465512727
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-8-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 2.311184903
# 0.235485119
# 0.5329063376224362
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-16-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 2.247600111
# 0.23675232400000001
# 0.5301897892466437
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-32-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 2.525644716
# 0.458302947
# 0.7012467284351185
# cpumemory
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-fa97bc89dcc1> in <module>
#      22 #     x=x+1
#      23     for add in SCEN:
# ---> 24         df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/"+add+"/mlperf_log_trace.json")
#      25         df1 = df[df["name"].isin(["Latency"])]
#      26         print(max(df1['issue_to_done']))
#
# <ipython-input-2-4df35bfbebfb> in trace_to_df(fname)
#       1 def trace_to_df(fname):
# ----> 2     with open(fname, "r") as f:
#       3         print(f)
#       4         j = json.load(f)
#       5     if type(j) == dict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/cpumemory-resnet-1-32-S-1-1/mlperf_log_trace.json'

# %%
BINS=12
color=["blue","green","yellow","red","orange","grey"]

for sc in ['none','cpumem','cpumemory']:
    print(sc)
    SCEN=[sc+'-resnet-1-32-S-1-10',
          sc+'-resnet-2-32-S-1-10',
             sc+'-resnet-4-32-S-1-10',
               sc+'-resnet-8-32-S-1-10',
          sc+'-resnet-16-32-S-1-10',
          sc+'-resnet-32-32-S-1-10']
    x=0
    for add in SCEN:
        df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp2/"+add+"/mlperf_log_trace.json")
        df1 = df[df["name"].isin(["Latency"])]
        print(max(df1['issue_delay']))
        print(np.median(df1['issue_delay']))
        print(np.mean(df1['issue_delay']))
    #     ax = df1['issue_to_done'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
    #     ax.set_title('Inference time (usec)');
    #     x = x+1
    #     plt.show()

        # Draw the density plot
        sns.distplot(df1['issue_delay'], hist = False, kde = True,
                     kde_kws = {'linewidth': 3},
                     label = SCEN[x])
        x=x+1

    # Plot formatting
    plt.legend(prop={'size': 16}, title = 'SCENARIO',loc='center left', bbox_to_anchor=(1, 0.5) )
    plt.title('Inference time')
    plt.xlabel('time (sec)')
    plt.ylabel('Density')
    plt.show()
# Out:
# none
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp2/none-resnet-1-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 45.186356288
# 16.8273507085
# 17.995179642579497
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp2/none-resnet-2-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 12.993258328
# 2.9290611909999997
# 4.183687234780793
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp2/none-resnet-4-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 9.836793175
# 1.11799313
# 2.7709924205287506
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp2/none-resnet-8-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 10.672057097
# 1.9341360145
# 3.246273317069216
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp2/none-resnet-16-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 5.467564821
# 0.0056318259999999995
# 1.1867893423950766
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp2/none-resnet-32-32-S-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 0.33735318
# 0.000113324
# 0.005210723444062481
# cpumem
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-50-6983114683dc> in <module>
#      12     x=0
#      13     for add in SCEN:
# ---> 14         df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp2/"+add+"/mlperf_log_trace.json")
#      15         df1 = df[df["name"].isin(["Latency"])]
#      16         print(max(df1['issue_delay']))
#
# <ipython-input-7-4df35bfbebfb> in trace_to_df(fname)
#       1 def trace_to_df(fname):
# ----> 2     with open(fname, "r") as f:
#       3         print(f)
#       4         j = json.load(f)
#       5     if type(j) == dict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp2/cpumem-resnet-1-32-S-1-10/mlperf_log_trace.json'

# %%
BINS=12
color=["black","blue","green","yellow","red","orange","grey"]
legend=["baseline","ANY-1ctn","ANY-2ctn","ANY-4ctn","ANY-8ctn","ANY-16ctn","ANY-32ctn"]
for sc in ['none','cpumemory']:
    print(sc)
    SCEN=[sc+'-resnet-1-32-S-1-1',
          sc+'-resnet-2-32-S-1-1',
             sc+'-resnet-4-32-S-1-1',
               sc+'-resnet-8-32-S-1-1',
          sc+'-resnet-16-32-S-1-1',
          sc+'-resnet-32-32-S-1-1']
    x=0
#     df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp2-baseline/none-resnet-1-32-S-1-1/mlperf_log_trace.json")
#     df1 = df[df["name"].isin(["Sample"])]
#     df1.reset_index(drop=True,inplace=True)
#     print(len(df1))
#     ax = df1['issue_to_done'].plot(figsize=figsize, color=color[x],label = legend[x])
#     x=x+1
    for add in SCEN:
        df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/"+add+"/mlperf_log_trace.json")
        df1 = df[df["name"].isin(["Latency"])]
        df1.reset_index(drop=True,inplace=True)
        ax = df1['issue_to_done'].plot(figsize=figsize, color=color[x],label = legend[x])
#         ax = df1['issue_delay'].plot(figsize=figsize, color=color[x],label = legend[x])
        ax.set_title('Individual inference time (usec)');
    #     ax.set(ylim=(0, 100))
        x=x+1
    ax.set_title('Individual inference time');
    plt.legend(prop={'size': 16}, title = 'SCENARIO',loc='center left', bbox_to_anchor=(1, 0.5) )
    plt.xlabel('Samples')
    plt.ylabel('Time (sec)')
    plt.savefig('s-iit'+sc+'done.pdf',bbox_inches='tight') 
    plt.show()
# Out:
# none
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-1-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-2-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-4-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-8-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-16-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-32-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# cpumemory
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-ab298f5db760> in <module>
#      18 #     x=x+1
#      19     for add in SCEN:
# ---> 20         df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/"+add+"/mlperf_log_trace.json")
#      21         df1 = df[df["name"].isin(["Latency"])]
#      22         df1.reset_index(drop=True,inplace=True)
#
# <ipython-input-2-4df35bfbebfb> in trace_to_df(fname)
#       1 def trace_to_df(fname):
# ----> 2     with open(fname, "r") as f:
#       3         print(f)
#       4         j = json.load(f)
#       5     if type(j) == dict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/cpumemory-resnet-1-32-S-1-1/mlperf_log_trace.json'

# %%
BINS=12
color=["black","blue","green","yellow","red","orange","grey"]
legend=["baseline","ANY-1ctn","ANY-2ctn","ANY-4ctn","ANY-8ctn","ANY-16ctn","ANY-32ctn"]
for sc in ['none','cpumemory']:
    print(sc)
    SCEN=[sc+'-resnet-1-32-S-1-1',
          sc+'-resnet-2-32-S-1-1',
             sc+'-resnet-4-32-S-1-1',
               sc+'-resnet-8-32-S-1-1',
          sc+'-resnet-16-32-S-1-1',
          sc+'-resnet-32-32-S-1-1']
    x=0
#     df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp2-baseline/none-resnet-1-32-S-1-1/mlperf_log_trace.json")
#     df1 = df[df["name"].isin(["Latency"])]
#     df1.reset_index(drop=True,inplace=True)
#     print(len(df1))
#     ax = df1['issue_delay'].plot(figsize=figsize, color=color[x],label = legend[x])
#     x=x+1
    for add in SCEN:
        df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/"+add+"/mlperf_log_trace.json")
        df1 = df[df["name"].isin(["Latency"])]
#         df1.reset_index(drop=True,inplace=True)
#         ax = df1['issue_to_done'].plot(figsize=figsize, color=color[x],label = legend[x])
        ax = df1['issue_delay'].plot(figsize=figsize, color=color[x],label = legend[x])
        ax.set_title('Individual inference time (usec)');
    #     ax.set(ylim=(0, 100))
        x=x+1
    ax.set_title('Individual issue delay time');
    plt.legend(prop={'size': 16}, title = 'SCENARIO',loc='center left', bbox_to_anchor=(1, 0.5) )
    plt.xlabel('Samples')
    plt.ylabel('Time (sec)')
    plt.savefig('s-iit'+sc+'delay.pdf',bbox_inches='tight') 
    plt.show()
# Out:
# none
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-1-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-2-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-4-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-8-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-16-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-32-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# cpumemory
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-b4b5892e0f8b> in <module>
#      18 #     x=x+1
#      19     for add in SCEN:
# ---> 20         df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/"+add+"/mlperf_log_trace.json")
#      21         df1 = df[df["name"].isin(["Latency"])]
#      22 #         df1.reset_index(drop=True,inplace=True)
#
# <ipython-input-2-4df35bfbebfb> in trace_to_df(fname)
#       1 def trace_to_df(fname):
# ----> 2     with open(fname, "r") as f:
#       3         print(f)
#       4         j = json.load(f)
#       5     if type(j) == dict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/cpumemory-resnet-1-32-S-1-1/mlperf_log_trace.json'

# %%
# df1 = df[df["name"].isin(["Latency"])]
# ax = df1['issue_to_done'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
# ax.set_title('Inference time (usec)');
# #ax.set(xlim=(0, 25000))
# plt.xticks(rotation=60)
# plt.show()

# ax = df1['issue_to_done'].plot(figsize=figsize)
# ax.set_title('Individual inference time (usec)');
# #ax.set(ylim=(0, 200))
# plt.show()


# # df1['issue_to_done'].describe()

# %%
# df1 = df[df["name"].isin(["QuerySamplesComplete"])]
# df1['delta'] = df1['ts'].diff()
# ax = df1['delta'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
# ax.set_title('Time between QuerySamplesComplete (usec)');
# plt.show()

# ax = df1['dur'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
# ax.set_title('Time QuerySamplesComplete (usec)');

# %%
BINS=12
color=["blue","green","yellow","red","orange","grey"]
for sc in ['none','cpumem','cpumemory']:
    print(sc)
    SCEN=[sc+'-resnet-1-32-S-1-1',
          sc+'-resnet-2-32-S-1-1',
             sc+'-resnet-4-32-S-1-1',
               sc+'-resnet-8-32-S-1-1',
          sc+'-resnet-16-32-S-1-1',
          sc+'-resnet-32-32-S-1-1']
    x=0
    for add in SCEN:
        df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/"+add+"/mlperf_log_trace.json")
        df1 = df[df["name"].isin(["QuerySamplesComplete"])]
        df1.sort_values("dur",inplace=True)
        df1.reset_index(drop=True,inplace=True)
        ax = df1['dur'].plot(figsize=figsize, color=color[x],label = SCEN[x])
        ax.set_title('Individual inference time (usec)');
#         ax.set(xlim=(11000, 12500))
        x=x+1
    plt.show()
# Out:
# none
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-1-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-2-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-4-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-8-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-16-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/none-resnet-32-32-S-1-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# cpumem
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-138ee743ea42> in <module>
#      11     x=0
#      12     for add in SCEN:
# ---> 13         df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/"+add+"/mlperf_log_trace.json")
#      14         df1 = df[df["name"].isin(["QuerySamplesComplete"])]
#      15         df1.sort_values("dur",inplace=True)
#
# <ipython-input-2-4df35bfbebfb> in trace_to_df(fname)
#       1 def trace_to_df(fname):
# ----> 2     with open(fname, "r") as f:
#       3         print(f)
#       4         j = json.load(f)
#       5     if type(j) == dict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp3/cpumem-resnet-1-32-S-1-1/mlperf_log_trace.json'
