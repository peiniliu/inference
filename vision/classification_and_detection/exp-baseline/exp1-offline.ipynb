# %% [markdown]
# # Tool to extract usefull information from mlperf trace

# %%
# %matplotlib inline
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

import json
import os
import seaborn as sns
from operator import itemgetter
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

figsize=(12, 8)
font=10

plt.figure(dpi=600)
plt.rc('xtick', labelsize=font) 
plt.rc('font', size=font)
sns.set(font_scale=1.4, style="whitegrid");

# %%
def trace_to_df(fname):
    with open(fname, "r") as f:
        print(f)
        j = json.load(f)
    if type(j) == dict:
        j = j['traceEvents']
        
    result = []
    for item in j:
        name = item['name']
        if name not in ["Latency", "Sample", "QuerySamplesComplete", "IssueQuery"]:
            continue

        args = item.get('args')
        d = {"ts": item['ts'], "name": name, "dur": item.get("dur")}

        if name == "Latency":
            d["issue_delay"] = args["issue_delay"] /1e9
            d["issue_to_done"] = args["issue_to_done"] / 1e9
            result.append(d)
        elif name == "Sample":
            if args:
                d["issue_start_ns"] = args["issue_start_ns"]
                d["complete_ns"] = args["complete_ns"]
                d["issue_to_done"] = (args["complete_ns"] - args["issue_start_ns"]) / 1e9
                result.append(d)
        elif name == "QuerySamplesComplete":
            result.append(d)
        elif name == "IssueQuery":
            result.append(d)

    df = pd.DataFrame(result)
    df = df.sort_values(by=["ts"])
    return df

BINS = 10

# %%
# Fixing bin edges
HIST_BINS = np.linspace(0, 1000000, 100)

# %%
df = trace_to_df('/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/none-resnet-1-32-O-32-1/mlperf_log_trace.json')
df.describe()
# Out:
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/none-resnet-1-32-O-32-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
#                  ts           dur  issue_start_ns   complete_ns  issue_to_done
# count  3.379300e+04  1.025000e+03         32768.0  3.276800e+04   32768.000000
# mean   3.693691e+06  8.662966e+04           508.0  1.168306e+11     116.830606
# std    2.293730e+07  2.773145e+06             0.0  6.423618e+10      64.236176
# min    1.534743e+05  3.894000e+00           508.0  4.166881e+09       4.166881
# 25%    1.534743e+05  7.312000e+00           508.0  6.097668e+10      60.976676
# 50%    1.534743e+05  8.690000e+00           508.0  1.171760e+11     117.175984
# 75%    1.534743e+05  1.211200e+01           508.0  1.722292e+11     172.229158
# max    2.253783e+08  8.878399e+07           508.0  2.252248e+11     225.224797

# %%
df["name"].unique()
# Out:
# array(['Sample', 'IssueQuery', 'QuerySamplesComplete'], dtype=object)

# %%
df
# Out:
#                  ts                  name     dur  issue_start_ns  \
# 0      1.792659e+05                Sample     NaN           790.0
# 22196  1.792659e+05                Sample     NaN           790.0
# 22195  1.792659e+05                Sample     NaN           790.0
# 22194  1.792659e+05                Sample     NaN           790.0
# 22193  1.792659e+05                Sample     NaN           790.0
# ...             ...                   ...     ...             ...
# 33660  2.334242e+08  QuerySamplesComplete  24.473             NaN
# 33693  2.334376e+08  QuerySamplesComplete   7.137             NaN
# 33726  2.334477e+08  QuerySamplesComplete   6.016             NaN
# 33759  2.334611e+08  QuerySamplesComplete   7.509             NaN
# 33792  2.334721e+08  QuerySamplesComplete  14.969             NaN
#
#         complete_ns  issue_to_done
# 0      8.425285e+09       8.425284
# 22196  1.584654e+11     158.465404
# 22195  1.584654e+11     158.465404
# 22194  1.584654e+11     158.465404
# 22193  1.584654e+11     158.465404
# ...             ...            ...
# 33660           NaN            NaN
# 33693           NaN            NaN
# 33726           NaN            NaN
# 33759           NaN            NaN
# 33792           NaN            NaN
#
# [33793 rows x 6 columns]

# %%
df1 = df[df["name"].isin(["Sample"])]
df1
# Out:
#                ts    name  dur  issue_start_ns   complete_ns  issue_to_done
# 0      179265.855  Sample  NaN           790.0  8.425285e+09       8.425284
# 22196  179265.855  Sample  NaN           790.0  1.584654e+11     158.465404
# 22195  179265.855  Sample  NaN           790.0  1.584654e+11     158.465404
# 22194  179265.855  Sample  NaN           790.0  1.584654e+11     158.465404
# 22193  179265.855  Sample  NaN           790.0  1.584654e+11     158.465404
# ...           ...     ...  ...             ...           ...            ...
# 11073  179265.855  Sample  NaN           790.0  8.154350e+10      81.543494
# 11018  179265.855  Sample  NaN           790.0  8.118370e+10      81.183696
# 11072  179265.855  Sample  NaN           790.0  8.154350e+10      81.543494
# 11066  179265.855  Sample  NaN           790.0  8.154350e+10      81.543494
# 11049  179265.855  Sample  NaN           790.0  8.152444e+10      81.524443
#
# [32768 rows x 6 columns]

# %%
df1 = df[df["name"].isin(["IssueQuery"])]
df1
# Out:
#                ts        name           dur  issue_start_ns  complete_ns  \
# 12672  179267.034  IssueQuery  9.330296e+07             NaN          NaN
#
#        issue_to_done
# 12672            NaN

# %%
df1 = df[df["name"].isin(["Latency"])]
df1
# Out:
# Empty DataFrame
# Columns: [ts, name, dur, issue_start_ns, complete_ns, issue_to_done]
# Index: []

# %%
df1 = df[df["name"].isin(["QuerySamplesComplete"])]
df1
# Out:
#                  ts                  name     dur  issue_start_ns  \
# 32     8.604551e+06  QuerySamplesComplete  26.373             NaN
# 65     8.670928e+06  QuerySamplesComplete  11.860             NaN
# 98     8.885673e+06  QuerySamplesComplete  11.299             NaN
# 131    8.902604e+06  QuerySamplesComplete  10.535             NaN
# 164    9.013204e+06  QuerySamplesComplete  10.313             NaN
# ...             ...                   ...     ...             ...
# 33660  2.334242e+08  QuerySamplesComplete  24.473             NaN
# 33693  2.334376e+08  QuerySamplesComplete   7.137             NaN
# 33726  2.334477e+08  QuerySamplesComplete   6.016             NaN
# 33759  2.334611e+08  QuerySamplesComplete   7.509             NaN
# 33792  2.334721e+08  QuerySamplesComplete  14.969             NaN
#
#        complete_ns  issue_to_done
# 32             NaN            NaN
# 65             NaN            NaN
# 98             NaN            NaN
# 131            NaN            NaN
# 164            NaN            NaN
# ...            ...            ...
# 33660          NaN            NaN
# 33693          NaN            NaN
# 33726          NaN            NaN
# 33759          NaN            NaN
# 33792          NaN            NaN
#
# [1024 rows x 6 columns]

# %% [markdown]
# # offline scenario

# %%
import pandas as pd
import glob
# import plotly.plotly as py
import plotly.graph_objs as go

from plotly import tools
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True) 

import numpy as np
import matplotlib.pyplot as plt
# include if using a Jupyter notebook
# %matplotlib inline

path = "/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/"
all_files = glob.glob(path + "*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True)
df.head()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#   benchmark k8senv  sbatch  numctn cscenario  cbatch  reps         qps  \
# 0    resnet   none      32       1   offline       1     1   99.611633
# 1    resnet   none      32       1   offline       2     1  111.888205
# 2    resnet   none      32       1   offline       4     1  124.161137
# 3    resnet   none      32       1   offline       8     1  135.516154
# 4    resnet   none      32       1   offline      16     1  139.588602
#
#          mean         p50         p80         p90         p95         p99  \
# 0  164.689851  164.642285  263.302158  296.141216  312.596354  325.742676
# 1  146.959430  147.055617  234.771776  263.894674  278.542244  290.184709
# 2  132.729634  132.820157  211.855608  238.090795  251.265350  261.775215
# 3  122.119555  122.037627  194.566137  218.788524  230.882423  240.349893
# 4  120.161750  119.957378  190.143934  213.343249  225.162685  234.263197
#
#          p999
# 0  328.704836
# 1  292.727467
# 2  263.839413
# 3  241.742344
# 4  234.654853

# %%
import pandas as pd
import glob
# import plotly.plotly as py
import plotly.graph_objs as go

from plotly import tools
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True) 

import numpy as np
import matplotlib.pyplot as plt
# include if using a Jupyter notebook
# %matplotlib inline
dfg = df
dfg
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#     benchmark k8senv  sbatch  numctn cscenario  cbatch  reps         qps  \
# 0      resnet   none      32       1   offline       1     1   99.611633
# 1      resnet   none      32       1   offline       2     1  111.888205
# 2      resnet   none      32       1   offline       4     1  124.161137
# 3      resnet   none      32       1   offline       8     1  135.516154
# 4      resnet   none      32       1   offline      16     1  139.588602
# ..        ...    ...     ...     ...       ...     ...   ...         ...
# 355    resnet   none      32      32   offline       2    10  105.454313
# 356    resnet   none      32      32   offline       4    10  113.122617
# 357    resnet   none      32      32   offline       8    10  119.357096
# 358    resnet   none      32      32   offline      16    10  119.920546
# 359    resnet   none      32      32   offline      32    10  124.623773
#
#            mean         p50         p80         p90         p95         p99  \
# 0    164.689851  164.642285  263.302158  296.141216  312.596354  325.742676
# 1    146.959430  147.055617  234.771776  263.894674  278.542244  290.184709
# 2    132.729634  132.820157  211.855608  238.090795  251.265350  261.775215
# 3    122.119555  122.037627  194.566137  218.788524  230.882423  240.349893
# 4    120.161750  119.957378  190.143934  213.343249  225.162685  234.263197
# ..          ...         ...         ...         ...         ...         ...
# 355   20.016994   20.041399   31.216490   34.995542   36.836307   37.739634
# 356   19.654216   19.774414   30.019613   33.453474   34.312230   34.892304
# 357   21.114762   21.371882   32.075487   33.121745   33.497649   33.883925
# 358   41.969857   42.979630   61.851387   65.206622   66.470225   67.793755
# 359   48.217480   48.445194   63.826749   64.244853   64.452354   64.987306
#
#            p999
# 0    328.704836
# 1    292.727467
# 2    263.839413
# 3    241.742344
# 4    234.654853
# ..          ...
# 355   38.214003
# 356   35.679248
# 357   34.284707
# 358   68.283737
# 359   65.706345
#
# [360 rows x 15 columns]

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from svglib.svglib import svg2rlg
from reportlab.graphics import renderPDF
from reportlab.pdfgen import canvas

from numpy import percentile, mean, std
import plotly.graph_objects as go

from plotly.offline import init_notebook_mode, iplot

import plotly.io as pio
pio.templates.default = "none"
# pio.templates.default = "simple_white"

import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd
# import plotly.express as px

# import seaborn library
import seaborn as sns

for x in ['qps','mean','p99','p999']:
    for cbatch in [1,2,4,8,16,32]:
        for model_name in ['resnet']:
            list_traces = []
#             for numctn in [1,2,4,8,16,32]: 
            dfg_bench = dfg[(dfg['benchmark']== model_name)  & (dfg['cbatch']==cbatch) & \
#                             (dfg['numctn']==numctn) &\
                        ((dfg['k8senv']=='none') |\
                         (dfg['k8senv']=='cpumem')| (dfg['k8senv']=='cpumemory'))]
#             print(dfg_bench)

            sns.boxplot(x = dfg_bench['k8senv'],
                        y = dfg_bench[x],
                        hue = dfg_bench['numctn'])
            plt.legend(prop={'size': 16}, title = 'NUMCTN',loc='center left', bbox_to_anchor=(1, 0.5) )
            plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from svglib.svglib import svg2rlg
from reportlab.graphics import renderPDF
from reportlab.pdfgen import canvas

from numpy import percentile, mean, std
import plotly.graph_objects as go

from plotly.offline import init_notebook_mode, iplot

import plotly.io as pio
pio.templates.default = "none"
# pio.templates.default = "simple_white"

import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd
# import plotly.express as px

for x in ['qps','mean','p99']:
    for cbatch in [16,32]:
        for model_name in ['resnet']:
            list_traces = []
            for numctn in [1,2,4,8,16,32]: 
                dfg_bench = dfg[(dfg['benchmark']== model_name)  & (dfg['cbatch']==cbatch) & (dfg['numctn']==numctn) &\
                            ((dfg['k8senv']=='none') |\
                             (dfg['k8senv']=='cpumem')| (dfg['k8senv']=='cpumemory'))]
#                 print(dfg_bench)


                #data
                trace = go.Scatter(
                    name="ctn"+str(numctn),
                    x=[ 'none','cpumem','cpu'],
                    y= dfg_bench[x].values.tolist(),
        #             error_y = dict(type='data', array=df1_bench['model_time_std'].values.tolist()),
                    opacity=0.7,
                    mode='markers'
                )
                list_traces.append(trace)



            #layout
            layout = go.Layout(
                title={
                    'text': "exp18(cpu32)= inter16,intra32 -> inter1,intra2; restapi=32" ,
                    'y':0.85,
                    'x':0.5,
                    'xanchor': 'center',
                    'yanchor': 'top'},
                width=1000,
                height=460,
                xaxis=dict(
                    title= "scenarios",
                    tickvals=[ 'none','cpumem','cpu'],
                    titlefont=dict(
                        size=10,
                        color='rgb(107, 107, 107)'
                    ),
                    tickfont=dict(
                        size=10,
                        color='rgb(107, 107, 107)'
                    )
                ),
                yaxis=dict(
                    title= x+"batch"+str(cbatch),
                    automargin=True,
                    titlefont=dict(
                        size=25,
                        color='rgb(107, 107, 107)'
                    ),
                    tickfont=dict(
                        size=25,
                        color='rgb(107, 107, 107)'
                    ),    
                ),
                legend=dict(
                    x=1.0,
                    y=1.0,
                    bgcolor='rgba(255, 255, 255, 0)',
                    bordercolor='rgba(255, 255, 255, 0)',
                    font = dict( size = 28)
                ),
                barmode='group',
                bargap=0.15,
                bargroupgap=0.08
        #         legend_orientation="h"
            )

        data = list_traces
        fig = go.Figure(data=data, layout=layout)
        fig.update_layout(legend_orientation="h")
        fig.show()    

    #     fig.write_image(path + model_name + k8senv +'.pdf')
# Out:
# <div>                            <div id="72e36c2b-9d98-4734-a2f9-ddc2fca7b5bd" class="plotly-graph-div" style="height:460px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72e36c2b-9d98-4734-a2f9-ddc2fca7b5bd")) {                    Plotly.newPlot(                        "72e36c2b-9d98-4734-a2f9-ddc2fca7b5bd",                        [{"mode": "markers", "name": "ctn1", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [141.95892287925597, 145.95982379804903, 146.07556536969852, 146.39262973961863, 146.70239915444296, 147.84071115606682, 146.78180970529442, 147.1826344758103, 145.9482570155973, 146.40229271144824, null, null, null, null, null, null, null, null, null, 141.41415646061847, 142.17649817706803, 144.03940871095816, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn2", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [177.53546248069512, 178.21746402924302, 178.91442304635893, 179.99449620729104, 179.81158351561146, 179.52254428727144, 180.37275943491792, 180.4538901979715, 180.4595954500196, 179.9688301826316, null, null, null, null, null, null, null, null, null, 183.3805980347553, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn4", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [179.8919628915447, 179.70292711061848, 181.12160400995745, 181.8697903616193, 180.83792907184525, 181.90103970484049, 180.9000668069139, 181.70194670739684, 181.51866463900603, 181.29389667892983, null, null, null, null, null, null, null, null, null, 184.94355675458849, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn8", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [178.948151645063, 177.59748205996243, 178.38684931582236, 179.64992158398982, 181.18756917938487, 181.3058481283772, 180.9387992245076, 180.87265418001704, 181.007180073754, 180.9150579183157, null, null, null, null, null, null, null, null, null, 186.63559906973177, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn16", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [178.39550218213276, 178.57839284469807, 177.73236573893152, 177.9448285911053, 178.87394893184836, 179.3431007995617, 179.98127150180528, 180.42795775335944, 180.79381035575156, 179.6714724101039, null, null, null, null, null, null, null, null, null, 184.43312590057937, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn32", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [179.46240245465486, 179.1080282321127, 178.32528654288535, 179.20494831397343, 179.96518295617958, 179.26915927087165, 176.84879987501284, 179.4829393441694, 179.23579598545615, 181.00928552833625, null, null, null, null, null, null, null, null, null, 180.56077992960948, null, null, null, null, null, null, null, null, null, null]}],                        {"bargap": 0.15, "bargroupgap": 0.08, "barmode": "group", "height": 460, "legend": {"bgcolor": "rgba(255, 255, 255, 0)", "bordercolor": "rgba(255, 255, 255, 0)", "font": {"size": 28}, "orientation": "h", "x": 1.0, "y": 1.0}, "template": {"data": {"scatter": [{"type": "scatter"}]}}, "title": {"text": "exp18(cpu32)= inter16,intra32 -> inter1,intra2; restapi=32", "x": 0.5, "xanchor": "center", "y": 0.85, "yanchor": "top"}, "width": 1000, "xaxis": {"tickfont": {"color": "rgb(107, 107, 107)", "size": 10}, "tickvals": ["none", "cpumem", "cpu"], "title": {"font": {"color": "rgb(107, 107, 107)", "size": 10}, "text": "scenarios"}}, "yaxis": {"automargin": true, "tickfont": {"color": "rgb(107, 107, 107)", "size": 25}, "title": {"font": {"color": "rgb(107, 107, 107 ...
#
# var gd = document.getElementById('72e36c2b-9d98-4734-a2f9-ddc2fca7b5bd');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>
# <div>                            <div id="2ccb5b5c-8c06-49ad-b5ad-70f5cc802db0" class="plotly-graph-div" style="height:460px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ccb5b5c-8c06-49ad-b5ad-70f5cc802db0")) {                    Plotly.newPlot(                        "2ccb5b5c-8c06-49ad-b5ad-70f5cc802db0",                        [{"mode": "markers", "name": "ctn1", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [140.43766787481994, 143.67519334208768, 144.4549929353466, 146.25394506979023, 148.59869110067254, 149.74574492493434, 148.04376955992305, 147.88413917704398, 147.69225983578917, 147.6233660850753, null, null, null, null, null, null, null, null, null, 139.85040790062078, 142.40163079622502, 145.85246471302025, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn2", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [176.9223022222317, 176.86489205005662, 178.7296872446586, 178.9840193935454, 178.74381866291114, 177.7176878413456, 178.03156052873098, 177.72981065855808, 178.37458206912382, 179.01888509398844, null, null, null, null, null, null, null, null, null, 182.54808075596495, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn4", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [181.66385987036813, 181.41528526072028, 183.11411382883932, 182.4649597791142, 183.39455779711355, 183.7667600509046, 180.7914226255464, 183.3995562655048, 183.01610755483665, 182.66136648738225, null, null, null, null, null, null, null, null, null, 186.80384723604368, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn8", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [180.1733663407756, 180.31866609164203, 179.76024359299382, 181.2260348329324, 181.8798461039172, 182.17766952327557, 181.92206486758585, 181.555014892182, 181.81813157103372, 181.98090278076617, null, null, null, null, null, null, null, null, null, 186.4420279311086, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn16", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [179.3689512528693, 178.5014085756787, 178.09182285272598, 178.97086607656564, 179.27406984775212, 180.00695993618473, 180.76128937420285, 181.06287214630228, 181.2150039993127, 181.02104188333809, null, null, null, null, null, null, null, null, null, 184.5524356685178, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn32", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [175.38373868462085, 176.86074344339906, 175.1882842544453, 175.96048638921448, 176.87640210685285, 176.87536844398505, 175.35088832448938, 176.7015945389689, 177.3347756379114, 177.06044922100764, null, null, null, null, null, null, null, null, null, 177.33102480918893, null, null, null, null, null, null, null, null, null, null]}],                        {"bargap": 0.15, "bargroupgap": 0.08, "barmode": "group", "height": 460, "legend": {"bgcolor": "rgba(255, 255, 255, 0)", "bordercolor": "rgba(255, 255, 255, 0)", "font": {"size": 28}, "orientation": "h", "x": 1.0, "y": 1.0}, "template": {"data": {"scatter": [{"type": "scatter"}]}}, "title": {"text": "exp18(cpu32)= inter16,intra32 -> inter1,intra2; restapi=32", "x": 0.5, "xanchor": "center", "y": 0.85, "yanchor": "top"}, "width": 1000, "xaxis": {"tickfont": {"color": "rgb(107, 107, 107)", "size": 10}, "tickvals": ["none", "cpumem", "cpu"], "title": {"font": {"color": "rgb(107, 107, 107)", "size": 10}, "text": "scenarios"}}, "yaxis": {"automargin": true, "tickfont": {"color": "rgb(107, 107, 107)", "size": 25}, "title": {"font": {"color": "rgb(107, 107, 107)" ...
#
# var gd = document.getElementById('2ccb5b5c-8c06-49ad-b5ad-70f5cc802db0');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>
# <div>                            <div id="b10de161-6dd2-4d4f-aeda-6a6ca7bf8d40" class="plotly-graph-div" style="height:460px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b10de161-6dd2-4d4f-aeda-6a6ca7bf8d40")) {                    Plotly.newPlot(                        "b10de161-6dd2-4d4f-aeda-6a6ca7bf8d40",                        [{"mode": "markers", "name": "ctn1", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [117.93903459361866, 114.22108795373876, 114.1459080565288, 114.05872892722266, 113.47547495002246, 112.7524093025957, 113.65059948624706, 113.60455116921386, 114.2195168244424, 113.69153737523632, null, null, null, null, null, null, null, null, null, 118.63380468034816, 118.1152570214751, 115.87053117459034, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn2", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [93.8561175252744, 93.56950627577734, 93.02441033052052, 92.52226854122851, 92.6477240181245, 92.71078237784424, 92.11024023833544, 92.2509749943047, 92.38375235933056, 92.41655208250243, null, null, null, null, null, null, null, null, null, 90.94494447601416, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn4", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [92.51064057145751, 92.24794318400586, 91.727961814688, 91.25436311862109, 91.65485327866456, 91.17160944559912, 91.4165600242461, 91.22664550043504, 91.31949418832129, 91.38152502375146, null, null, null, null, null, null, null, null, null, 89.37257982108301, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn8", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [92.76421592104587, 92.99672785935256, 92.53712715537694, 92.0828349406919, 91.47700537745752, 91.6584512961631, 91.60103505894092, 91.70165059673484, 91.57446845999804, 91.72424853190184, null, null, null, null, null, null, null, null, null, 88.76302069933642, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn16", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [92.4923032224868, 92.45628970953028, 92.50794405539844, 92.80554225278466, 92.03592537626172, 91.85997603049267, 91.71644443847264, 91.66594244600144, 91.63320654330371, 91.871080876126, null, null, null, null, null, null, null, null, null, 89.15869203238623, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn32", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [91.31379891623877, 91.46375049959178, 91.74680702845508, 91.7230941304795, 91.5771115656548, 91.471359046645, 91.57241450111133, 91.61780391510254, 91.27526763144238, 91.18765219322754, null, null, null, null, null, null, null, null, null, 89.30595071890039, null, null, null, null, null, null, null, null, null, null]}],                        {"bargap": 0.15, "bargroupgap": 0.08, "barmode": "group", "height": 460, "legend": {"bgcolor": "rgba(255, 255, 255, 0)", "bordercolor": "rgba(255, 255, 255, 0)", "font": {"size": 28}, "orientation": "h", "x": 1.0, "y": 1.0}, "template": {"data": {"scatter": [{"type": "scatter"}]}}, "title": {"text": "exp18(cpu32)= inter16,intra32 -> inter1,intra2; restapi=32", "x": 0.5, "xanchor": "center", "y": 0.85, "yanchor": "top"}, "width": 1000, "xaxis": {"tickfont": {"color": "rgb(107, 107, 107)", "size": 10}, "tickvals": ["none", "cpumem", "cpu"], "title": {"font": {"color": "rgb(107, 107, 107)", "size": 10}, "text": "scenarios"}}, "yaxis": {"automargin": true, "tickfont": {"color": "rgb(107, 107, 107)", "size": 25}, "title": {"font": {"color": "rgb(107, 107, 107)", "size": 25}, "text": "meanbatch16"}}},            ...
#
# var gd = document.getElementById('b10de161-6dd2-4d4f-aeda-6a6ca7bf8d40');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>
# <div>                            <div id="e9e2ac4e-d74e-4747-a2fe-8f0545493859" class="plotly-graph-div" style="height:460px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e9e2ac4e-d74e-4747-a2fe-8f0545493859")) {                    Plotly.newPlot(                        "e9e2ac4e-d74e-4747-a2fe-8f0545493859",                        [{"mode": "markers", "name": "ctn1", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [121.68115743496094, 117.34286645289454, 117.03519179999024, 115.8440141413203, 114.15110861168944, 113.27730863883396, 114.60521279011914, 114.37458275213086, 114.69107678032714, 114.76659254732714, null, null, null, null, null, null, null, null, null, 121.76803509012598, 119.89060027271388, 116.10592025598928, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn2", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [95.76639260344824, 95.61306305470704, 94.59215781345702, 94.15539325262988, 94.4065044329336, 94.57585106498048, 94.97703345479783, 95.14220630251369, 94.61255788009962, 94.34184208374607, null, null, null, null, null, null, null, null, null, 92.71165700065724, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn4", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [92.78161003592284, 92.68001913257228, 92.06844585967188, 92.3765585967246, 91.67965845779491, 91.54730029544238, 92.03684908622556, 91.63319086673732, 91.96202686859276, 92.0728880867578, null, null, null, null, null, null, null, null, null, 90.16282777052442, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn8", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [93.1735038686289, 93.38986000627249, 93.33656380890623, 92.37821186754492, 92.45123091268748, 92.46830263446388, 92.80992376966796, 92.78339974059864, 92.24469699157618, 92.23165674213088, null, null, null, null, null, null, null, null, null, 89.96636371004688, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn16", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [93.73063657093653, 93.84623723864452, 94.39139300287988, 93.94561479967382, 93.51415460500098, 92.9149931406455, 93.08841125178908, 93.10866213707618, 92.8175733940127, 92.94318670715626, null, null, null, null, null, null, null, null, null, 90.79898928290724, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn32", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [94.84851813118068, 94.78379089525195, 94.62834265461036, 94.45191290202928, 94.7244464920957, 94.2052386568662, 94.8211557036084, 94.78486557708204, 94.26446692989452, 94.42145843248242, null, null, null, null, null, null, null, null, null, 92.85275525162696, null, null, null, null, null, null, null, null, null, null]}],                        {"bargap": 0.15, "bargroupgap": 0.08, "barmode": "group", "height": 460, "legend": {"bgcolor": "rgba(255, 255, 255, 0)", "bordercolor": "rgba(255, 255, 255, 0)", "font": {"size": 28}, "orientation": "h", "x": 1.0, "y": 1.0}, "template": {"data": {"scatter": [{"type": "scatter"}]}}, "title": {"text": "exp18(cpu32)= inter16,intra32 -> inter1,intra2; restapi=32", "x": 0.5, "xanchor": "center", "y": 0.85, "yanchor": "top"}, "width": 1000, "xaxis": {"tickfont": {"color": "rgb(107, 107, 107)", "size": 10}, "tickvals": ["none", "cpumem", "cpu"], "title": {"font": {"color": "rgb(107, 107, 107)", "size": 10}, "text": "scenarios"}}, "yaxis": {"automargin": true, "tickfont": {"color": "rgb(107, 107, 107)", "size": 25}, "title": {"font": {"color": "rgb(107, 107, 107)", "size": 25}, "text": "meanbatch32"}}},   ...
#
# var gd = document.getElementById('e9e2ac4e-d74e-4747-a2fe-8f0545493859');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>
# <div>                            <div id="76000382-f448-45b7-8e85-4ef99411d363" class="plotly-graph-div" style="height:460px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76000382-f448-45b7-8e85-4ef99411d363")) {                    Plotly.newPlot(                        "76000382-f448-45b7-8e85-4ef99411d363",                        [{"mode": "markers", "name": "ctn1", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [230.102015399, 223.552093805, 223.760215425, 223.065091123, 222.591287067, 220.743981772, 222.308973498, 221.968748534, 223.773943995, 222.953847074, null, null, null, null, null, null, null, null, null, 231.073436144, 229.752501076, 226.765485394, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn2", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [183.474570919, 183.122111548, 182.189819496, 181.022095615, 181.453965942, 181.340233912, 180.558554993, 180.793378199, 180.786550402, 180.955697249, null, null, null, null, null, null, null, null, null, 178.079039046, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn4", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [181.461588135, 180.294276491, 179.686168188, 178.717738697, 179.693404006, 178.623226736, 179.31343346, 178.732975986, 178.483789464, 179.021821775, null, null, null, null, null, null, null, null, null, 174.704819082, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn8", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [181.714416167, 182.309386697, 181.986728641, 180.016466613, 179.158972238, 179.12312476, 179.548850652, 179.723438541, 179.695931061, 179.371237389, null, null, null, null, null, null, null, null, null, 173.601593687, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn16", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [181.697783027, 181.405539924, 181.867080437, 182.058476179, 180.423352929, 180.570812422, 180.089864293, 180.077403499, 179.866299454, 179.723980862, null, null, null, null, null, null, null, null, null, 174.608259123, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn32", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [179.199582196, 179.245303062, 179.628602715, 179.622557855, 178.898070536, 178.635290858, 179.477587514, 178.890013254, 178.646253605, 178.407057495, null, null, null, null, null, null, null, null, null, 174.820364185, null, null, null, null, null, null, null, null, null, null]}],                        {"bargap": 0.15, "bargroupgap": 0.08, "barmode": "group", "height": 460, "legend": {"bgcolor": "rgba(255, 255, 255, 0)", "bordercolor": "rgba(255, 255, 255, 0)", "font": {"size": 28}, "orientation": "h", "x": 1.0, "y": 1.0}, "template": {"data": {"scatter": [{"type": "scatter"}]}}, "title": {"text": "exp18(cpu32)= inter16,intra32 -> inter1,intra2; restapi=32", "x": 0.5, "xanchor": "center", "y": 0.85, "yanchor": "top"}, "width": 1000, "xaxis": {"tickfont": {"color": "rgb(107, 107, 107)", "size": 10}, "tickvals": ["none", "cpumem", "cpu"], "title": {"font": {"color": "rgb(107, 107, 107)", "size": 10}, "text": "scenarios"}}, "yaxis": {"automargin": true, "tickfont": {"color": "rgb(107, 107, 107)", "size": 25}, "title": {"font": {"color": "rgb(107, 107, 107)", "size": 25}, "text": "p99batch16"}}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('76000382-f448-45b7-8e85-4ef99411d363');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>
# <div>                            <div id="30adce9d-dd9a-4e6f-85d8-9cc8ed4ba37b" class="plotly-graph-div" style="height:460px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30adce9d-dd9a-4e6f-85d8-9cc8ed4ba37b")) {                    Plotly.newPlot(                        "30adce9d-dd9a-4e6f-85d8-9cc8ed4ba37b",                        [{"mode": "markers", "name": "ctn1", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [233.011985862, 227.70925714, 226.494316728, 223.595841111, 220.132686406, 218.415850995, 221.015418888, 221.170954469, 221.678751889, 221.73130418, null, null, null, null, null, null, null, null, null, 233.948015097, 229.860160971, 224.358399413, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn2", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [184.430173997, 184.1476132, 182.523715127, 181.726184056, 182.286913696, 183.386479302, 183.15902902, 183.48523917, 182.437191933, 182.107975754, null, null, null, null, null, null, null, null, null, 178.633308697, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn4", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [179.466230996, 179.416410371, 178.428901763, 178.240219378, 177.555400371, 177.204225508, 178.293770788, 177.469785954, 178.084087187, 178.222402455, null, null, null, null, null, null, null, null, null, 174.062304731, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn8", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [180.329112627, 180.646208301, 180.483444927, 179.121374505, 179.001645877, 178.975581164, 179.234428962, 179.339319336, 178.549558857, 178.685087176, null, null, null, null, null, null, null, null, null, 174.318350444, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn16", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [180.757630151, 181.528171044, 182.459468341, 181.90386923, 181.277011096, 179.766520003, 180.15952632, 179.910568403, 179.713564349, 179.532879536, null, null, null, null, null, null, null, null, null, 175.513198061, null, null, null, null, null, null, null, null, null, null]}, {"mode": "markers", "name": "ctn32", "opacity": 0.7, "type": "scatter", "x": ["none", "cpumem", "cpu"], "y": [183.555643875, 183.3278074, 183.376428008, 182.466353893, 183.291595847, 182.552420475, 183.345310403, 183.295727058, 182.20590679, 182.807115812, null, null, null, null, null, null, null, null, null, 179.75494461, null, null, null, null, null, null, null, null, null, null]}],                        {"bargap": 0.15, "bargroupgap": 0.08, "barmode": "group", "height": 460, "legend": {"bgcolor": "rgba(255, 255, 255, 0)", "bordercolor": "rgba(255, 255, 255, 0)", "font": {"size": 28}, "orientation": "h", "x": 1.0, "y": 1.0}, "template": {"data": {"scatter": [{"type": "scatter"}]}}, "title": {"text": "exp18(cpu32)= inter16,intra32 -> inter1,intra2; restapi=32", "x": 0.5, "xanchor": "center", "y": 0.85, "yanchor": "top"}, "width": 1000, "xaxis": {"tickfont": {"color": "rgb(107, 107, 107)", "size": 10}, "tickvals": ["none", "cpumem", "cpu"], "title": {"font": {"color": "rgb(107, 107, 107)", "size": 10}, "text": "scenarios"}}, "yaxis": {"automargin": true, "tickfont": {"color": "rgb(107, 107, 107)", "size": 25}, "title": {"font": {"color": "rgb(107, 107, 107)", "size": 25}, "text": "p99batch32"}}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('30adce9d-dd9a-4e6f-85d8-9cc8ed4ba37b');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
BINS=12
color=["blue","green","yellow","red","orange","grey"]
SCEN=[
    'none-resnet-1-32-O-32-1',
      'none-resnet-2-32-O-32-1',
            'none-resnet-4-32-O-32-1',
           'none-resnet-8-32-O-32-1',
      'none-resnet-16-32-O-32-1',
      'none-resnet-32-32-O-32-1'
]
x=0
for add in SCEN:
    df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/"+add+"/mlperf_log_trace.json")
    df1 = df[df["name"].isin(["IssueQuery"])]
    print(df1)
#     ax = df1['dur'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
#     ax.set_title('IssueQuery duration (usec)');
#     x=x+1
#     plt.show()

# df1['delta'].describe()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-8ced2775ae37> in <module>
#      11 x=0
#      12 for add in SCEN:
# ---> 13     df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/"+add+"/mlperf_log_trace.json")
#      14     df1 = df[df["name"].isin(["IssueQuery"])]
#      15     print(df1)
#
# <ipython-input-7-4df35bfbebfb> in trace_to_df(fname)
#       1 def trace_to_df(fname):
# ----> 2     with open(fname, "r") as f:
#       3         print(f)
#       4         j = json.load(f)
#       5     if type(j) == dict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/none-resnet-1-32-O-32-1/mlperf_log_trace.json'

# %%
# # for SingleStream
# if True:
#     df1 = df[df["name"].isin(["QuerySamplesComplete"])]
#     ax = df1['dur'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
#     ax.set_title('Inference time (usec)');
#     plt.show()
#     ax = df1['dur'].plot(figsize=figsize)
#     ax.set(ylim=(0, 600))
#     ax.set_title('Individual inference time (usec)');

# %%
BINS=12
color=["blue","green","yellow","red","orange","grey"]
for hardware in ['cpumemory']:
    for batch in ['1','2','4','8','16','32']:
        SCEN=[
            hardware+'-resnet-1-32-O-'+batch+'-10',
              hardware+'-resnet-2-32-O-'+batch+'-10',
                    hardware+'-resnet-4-32-O-'+batch+'-10',
                   hardware+'-resnet-8-32-O-'+batch+'-10',
              hardware+'-resnet-16-32-O-'+batch+'-10',
              hardware+'-resnet-32-32-O-'+batch+'-10'
        ]
        x=0
        for add in SCEN:
            df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/"+add+"/mlperf_log_trace.json")
            df1 = df[df["name"].isin(["QuerySamplesComplete"])]
            print(len(df1))
            print(max(df1['dur']))
            print(np.median(df1['dur']))
            print(np.mean(df1['dur']))
        #     ax = df1['issue_to_done'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
        #     ax.set_title('Inference time (usec)');
        #     x = x+1
        #     plt.show()

            # Draw the density plot
            sns.distplot(df1['dur'], hist = False, kde = True,
                         kde_kws = {'linewidth': 3},
                         label = SCEN[x])
            x=x+1

        # Plot formatting
        plt.legend(prop={'size': 16}, title = 'SCENARIO',loc='center left', bbox_to_anchor=(1, 0.5) )
        plt.title('Inference time (usec) -- batch'+str(batch))
        plt.xlabel('time (usec)')
        plt.ylabel('Density')
        plt.show()
# Out:
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-1-32-O-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 32768
# 82.284
# 3.12
# 3.373889739990246
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-2-32-O-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 32768
# 84.302
# 3.133
# 3.4216262817382987
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-4-32-O-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 32768
# 90.963
# 3.062
# 3.324547515869146
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-8-32-O-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 32768
# 86.055
# 2.927
# 3.171759765624984
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-16-32-O-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 32768
# 486.477
# 3.077
# 3.465378875732416
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-32-32-O-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 32768
# 349.184
# 3.043
# 3.328828430175794
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-1-32-O-2-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 16384
# 97.358
# 3.63
# 4.335407958984355
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-2-32-O-2-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 16384
# 67.317
# 3.547
# 3.9742299194336006
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-4-32-O-2-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 16384
# 136.434
# 3.437
# 3.8661093139648637
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-8-32-O-2-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 16384
# 109.778
# 3.63
# 4.123565979003919
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-16-32-O-2-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 16384
# 73.777
# 3.397
# 3.850132385253899
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-32-32-O-2-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 16384
# 76.696
# 3.52
# 3.970404235839849
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-1-32-O-4-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 8192
# 87.167
# 3.923
# 4.650084350585942
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-2-32-O-4-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 8192
# 114.074
# 4.147
# 4.800302856445322
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-4-32-O-4-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 8192
# 66.357
# 4.173500000000001
# 4.8222559814453225
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-8-32-O-4-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 8192
# 56.981
# 4.18
# 4.811119873046884
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-16-32-O-4-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 8192
# 113.902
# 4.217
# 5.3468829345703
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-32-32-O-4-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 8192
# 79.822
# 4.372
# 5.373973510742185
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-1-32-O-8-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 4096
# 74.358
# 5.117
# 6.155856689453122
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-2-32-O-8-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 4096
# 80.751
# 5.037
# 6.868924804687495
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-4-32-O-8-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 4096
# 98.148
# 5.172
# 6.329106933593741
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-8-32-O-8-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 4096
# 85.886
# 5.0755
# 6.257025146484378
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-16-32-O-8-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 4096
# 111.223
# 5.43
# 6.912212890624993
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-32-32-O-8-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 4096
# 94.194
# 4.987500000000001
# 6.072080810546893
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-1-32-O-16-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 2048
# 72.831
# 6.1805
# 7.746193847656256
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-2-32-O-16-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 2048
# 81.47
# 6.468
# 7.894782714843762
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-4-32-O-16-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 2048
# 71.476
# 6.351
# 8.068601562499984
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-8-32-O-16-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 2048
# 72.862
# 6.1175
# 7.546264160156259
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-16-32-O-16-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 2048
# 110.111
# 6.3225
# 8.857890625000017
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-32-32-O-16-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 2048
# 80.815
# 6.5825
# 8.392730957031246
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-1-32-O-32-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 1024
# 92.065
# 8.946
# 11.710781249999993
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-2-32-O-32-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 1024
# 66.036
# 8.219999999999999
# 10.470191406249995
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-4-32-O-32-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 1024
# 65.733
# 8.463000000000001
# 10.604744140625007
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-8-32-O-32-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 1024
# 62.62
# 8.2865
# 10.466889648437496
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-16-32-O-32-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 1024
# 59.201
# 8.411000000000001
# 10.670812499999997
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp1/cpumemory-resnet-32-32-O-32-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 1024
# 77.494
# 8.8055
# 10.963077148437502

# %%
BINS=12
color=["blue","green","yellow","red","orange","grey"]
for hardware in ['none']:
    for batch in ['1','2','4','8','16','32']:
#     for batch in ['16','32']:
        SCEN=[
#                 hardware+'-resnet-1-32-O-'+batch+'-10',
#                   hardware+'-resnet-2-32-O-'+batch+'-10',
#                         hardware+'-resnet-4-32-O-'+batch+'-10',
#                        hardware+'-resnet-8-32-O-'+batch+'-10',
#                   hardware+'-resnet-16-32-O-'+batch+'-10',
                  hardware+'-resnet-32-32-O-'+batch+'-10'
            ]
        x=0
        for add in SCEN:
            df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/"+add+"/mlperf_log_trace.json")
            df1 = df[df["name"].isin(["Sample"])]
    #         print(max(df1['dur']))
    #         print(np.median(df1['dur']))
    #         print(np.mean(df1['dur']))
        #     ax = df1['issue_to_done'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
        #     ax.set_title('Inference time (usec)');
        #     x = x+1
        #     plt.show()

            # Draw the density plot
            sns.distplot(df1['issue_to_done'], hist = False, kde = True,
                         kde_kws = {'linewidth': 3},
                         label = SCEN[x])
            x=x+1

        # Plot formatting
        plt.legend(prop={'size': 16}, title = 'SCENARIO',loc='center left', bbox_to_anchor=(1, 0.5) )
        plt.title('Inference time (usec) -- batch'+str(batch))
        plt.xlabel('time (usec)')
        plt.ylabel('Density')
        plt.show()
# Out:
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/none-resnet-32-32-O-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/none-resnet-32-32-O-2-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/none-resnet-32-32-O-4-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/none-resnet-32-32-O-8-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/none-resnet-32-32-O-16-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/none-resnet-32-32-O-32-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>

# %%
BINS=12
color=["blue","green","yellow","red","orange","grey"]
# for batch in ['32']:
for batch in ['1','2','4','8','16','32']:
    SCEN=[
#         'none-resnet-1-32-O-'+batch+'-10',
#           'none-resnet-2-32-O-'+batch+'-10',
#                 'none-resnet-4-32-O-'+batch+'-10',
#                'none-resnet-8-32-O-'+batch+'-10',
#           'none-resnet-16-32-O-'+batch+'-10',
          'none-resnet-32-32-O-'+batch+'-10'
    ]
    x=0
    for add in SCEN:
        df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/"+add+"/mlperf_log_trace.json")
        df1 = df[df["name"].isin(["QuerySamplesComplete"])]
        print(len(df1))
#         df1.sort_values("dur",inplace=True)
#         df1.reset_index(drop=True,inplace=True)
        df1.sort_index(inplace=True)
        df1.reset_index(drop=True,inplace=True)
        
        ax = df1['dur'].plot(figsize=figsize, color=color[x],label = SCEN[x])
        ax.set_title('Individual inference time (usec)');
#         ax.set(xlim=(0, 50))
#         ax.set(ylim=(0, 50))
        x=x+1
    plt.legend(prop={'size': 16}, title = 'SCENARIO',loc='center left', bbox_to_anchor=(1, 0.5) )
    plt.show()
    plt.xlabel('#QuerySamples')
# Out:
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/none-resnet-32-32-O-1-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 4096
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/none-resnet-32-32-O-2-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 2048
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/none-resnet-32-32-O-4-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 1024
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/none-resnet-32-32-O-8-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 512
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/none-resnet-32-32-O-16-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 256
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/none-resnet-32-32-O-32-10/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 128

# %%
df1 = df[df["name"].isin(["Sample"])]
len(df1)
# Out:
# 32768

# %%
BINS=12
color=["blue","green","yellow","red","orange","grey"]
for hardware in ['none','cpumemory']:
    # for batch in ['1','2','4','8','16','32']:
    for batch in ['32']:
        SCEN=[
                    hardware+'-resnet-1-32-O-'+batch+'-1',
                      hardware+'-resnet-2-32-O-'+batch+'-1',
                            hardware+'-resnet-4-32-O-'+batch+'-1',
                           hardware+'-resnet-8-32-O-'+batch+'-1',
                      hardware+'-resnet-16-32-O-'+batch+'-1',
                      hardware+'-resnet-32-32-O-'+batch+'-1'
                ]
        x=0
        for add in SCEN:
            df = trace_to_df("/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/"+add+"/mlperf_log_trace.json")
            df1 = df[df["name"].isin(["Sample"])]
    #         print(df1)
            print(len(df1))

    #         df1.sort_values("issue_to_done",inplace=True)
    #         df1.reset_index(drop=True,inplace=True)

            df1.sort_index(inplace=True)
            df1.reset_index(inplace=True)
            df1.reset_index(inplace=True)
            df1["level_0"] = df1["level_0"] / df1['issue_to_done']
#             print(df1)

    #         print(df2)
    #         print(len(df1))
            ax = df1['level_0'].plot(figsize=figsize, color=color[x],label = SCEN[x],marker='.', linestyle='none')
            ax.set_title('Individual inference time (sec)');
    #         ax.set(ylim=(0, 20))
    #         ax.set(xlim=(-1, 4096))
            x=x+1
        plt.legend(prop={'size': 16}, title = 'SCENARIO',loc='center left', bbox_to_anchor=(1, 0.5) )
        plt.show()
        plt.xlabel('#QuerySamples')
# Out:
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/none-resnet-1-32-O-32-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 32768
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/none-resnet-2-32-O-32-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 32768
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/none-resnet-4-32-O-32-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 32768
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/none-resnet-8-32-O-32-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 32768
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/none-resnet-16-32-O-32-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 32768
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/none-resnet-32-32-O-32-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 32768
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/cpumemory-resnet-1-32-O-32-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 4096
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/cpumemory-resnet-2-32-O-32-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 4096
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/cpumemory-resnet-4-32-O-32-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 4096
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/cpumemory-resnet-8-32-O-32-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 4096
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/cpumemory-resnet-16-32-O-32-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 4096
# <_io.TextIOWrapper name='/gpfs/bsc_home/xpliu/inference/vision/classification_and_detection/exp-baseline/cpumemory-resnet-32-32-O-32-1/mlperf_log_trace.json' mode='r' encoding='UTF-8'>
# 4096

# %%
df1 = df[df["name"].isin(["QuerySamplesComplete"])]
ax = df1['dur'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
ax.set_title('Inference time (usec)');
#ax.set(xlim=(0, 25000))
plt.xticks(rotation=60)
plt.show()

ax = df1['dur'].plot(figsize=figsize)
ax.set_title('Individual inference time (usec)');
#ax.set(ylim=(0, 200))
plt.show()


# df1['issue_to_done'].describe()

# %%
df1 = df[df["name"].isin(["QuerySamplesComplete"])]
df1['delta'] = df1['ts'].diff()
ax = df1['delta'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
ax.set_title('Time between QuerySamplesComplete (usec)');
plt.show()

ax = df1['dur'].plot.hist(bins=BINS, alpha=0.5, figsize=figsize)
ax.set_title('Time QuerySamplesComplete (usec)');
